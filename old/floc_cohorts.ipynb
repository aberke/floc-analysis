# %%
from datetime import datetime
import sys
sys.path.append('..')

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
panels_df = pd.read_csv("../output/all_panels.csv", index_col=0)

# %%
panels_df.head()
# Out:
#     machine_id  household_income  racial_background  stratify  panel_id
# 0  217187453.0                 1                1.0  1.0, 1.0         0
# 1  161205582.0                 1                1.0  1.0, 1.0         0
# 2  228664045.0                 1                1.0  1.0, 1.0         0
# 3  206048074.0                 1                1.0  1.0, 1.0         0
# 4  225801506.0                 1                1.0  1.0, 1.0         0

# %%
N_machines = panels_df.groupby('panel_id')['machine_id'].count()[0]
print("\n%s = N machines per panel" % N_machines)
# Out:
# 12146 = N machines per panel

# %% [markdown]
# We know from exploring the sessions data that only about 35-40% machines have at least 7 domains each week. How many cohorts if cohort size K=50, ...

# %%
K = 50
print('max expected number of cohorts if K = %s ?' % K)
print(0.36*panels_df.groupby('panel_id')['machine_id'].count()[0] / K)
K = 100
print('max expected number of cohorts if K = %s ?' % K)
print(0.36*panels_df.groupby('panel_id')['machine_id'].count()[0] / K)
# Out:
# max expected number of cohorts if K = 50 ?
# 87.45119999999999
# max expected number of cohorts if K = 100 ?
# 43.72559999999999

# %% [markdown]
# We use a library developed to replicate chrome FLoC cohorts for the origin trial.
#
# We just use the simhash function from this library. We briefly test its full simulation functionality, which uses that simhash, to show it correctly replicates the cohort ID.

# %%
import floc

# sanity check: The same host list used in the GO and python implementations generate
# the same cohort ID
host_list = [
    'www.nikkei.com',
    'jovi0608.hatenablog.com',
    'www.nikkansports.com',
    'www.yahoo.co.jp',
    'www.sponichi.co.jp',
    'www.cnn.co.jp',
    'floc.glitch.me',
    'html5.ohtsu.org',
]
assert(floc.simulate(host_list) == 21454)

# %%
# does it matter if this is a host or set?
# No
host_set = set(host_list)
assert(floc.simulate(host_set) == 21454)
host_set
# Out:
# {'floc.glitch.me',
#  'html5.ohtsu.org',
#  'jovi0608.hatenablog.com',
#  'www.cnn.co.jp',
#  'www.nikkansports.com',
#  'www.nikkei.com',
#  'www.sponichi.co.jp',
#  'www.yahoo.co.jp'}

# %%
# here is an example of a domain list for a cohort deemed sensitive
sensitive_cohort_domain_list = [
    "www.dominos.com",
    "shop.lululemon.com",
    "www.homedepot.com",
    "www.ticketliquidator.com",
    "www.livenation.com",
    "www.tracfone.com",
    "www.officedepot.com"
]
try:
    floc.simulate(sensitive_cohort_domain_list)
except Exception as e:
    print("SimulateError:", e)
floc.simulate(sensitive_cohort_domain_list, check_sensiveness=False)
# Out:
# SimulateError: blocked
# 24884

# %% [markdown]
# ## Compute cohorts

# %% [markdown]
# ### Compute fake cohorts with transactions data
#
# Make table mapping machine_ids to domains.
#
# TODO: update this step to use the real sessions data (once we have it)
#
# Here we make fake sessions/domains data, by using the transactions data. Here the domains are the domains where the transactions for a user were made.
#
# But we need at least 7 domains and most user data is sparse... so we insert more domains into a user's weekly domain history.

# %%
transactions_fpath = '../data/comscore/2017/transactions.csv'
transactions_df = pd.read_csv(transactions_fpath,
                              parse_dates=['event_date'],
                              encoding="ISO-8859-1")[
    ['machine_id', 'event_date', 'domain_name']
]
(transactions_df
 .drop('machine_id',axis=1)
 .dropna()
).head()
# Out:
# /Users/aberke/projects/floc-analysis/venv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    event_date          domain_name
# 25 2017-01-04  verizonwireless.com
# 26 2017-03-22  verizonwireless.com
# 27 2017-01-07  verizonwireless.com
# 28 2017-03-13  verizonwireless.com
# 29 2017-02-28  verizonwireless.com

# %%
tdf = (transactions_df
 .assign(week=lambda x: x.event_date.dt.week)
 .dropna()
 .groupby(['machine_id', 'week'])
 .agg({'domain_name': set}).reset_index()
       .assign(n_domains=lambda x: x.domain_name.map(len))
       .assign(domain_name=lambda x: x.domain_name.map(lambda y: "|".join(list(y))))
      )
# Out:
# /Users/aberke/projects/floc-analysis/venv/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
(tdf
 .sort_values('n_domains', ascending=False)
 .drop('machine_id', axis=1)
).head(10)
# Out:
#        week                                        domain_name  n_domains
# 24571    10  nordstromrack.com|amazon.com|expedia.com|ebay....          8
# 40382    12  avis.com|amazon.com|budget.com|expedia.com|orb...          7
# 22464     1  southwest.com|nordstrom.com|bestwestern.com|hy...          7
# 22470     7  bestbuy.com|nordstromrack.com|amazon.com|dicks...          6
# 13162     1  carters.com|amazon.com|gap.com|sephora.com|6pm...          6
# 1275      5  overstock.com|amazon.com|etsy.com|walmart.com|...          5
# 11114     4  booking.com|bestwestern.com|ticketmaster.com|t...          5
# 22543     1  hertz.com|amazon.com|dsw.com|searspartsdirect....          5
# 24967    10  disneystore.com|shutterfly.com|qvc.com|kohls.c...          5
# 17162     8  shutterfly.com|carters.com|officedepot.com|gap...          5

# %% [markdown]
# There are not enough domains per machine ^.
#
# Pad the domain histories for each machine to have at least 7 per machine.

# %%
import itertools
unique_domains = list(set(itertools.chain(*[d.split("|") for d in tdf.domain_name])))

def pad_domains(l, s):
    n = 7 - len(l)
    if n > 0:
        return list(l) + list(np.random.choice(s, n))
    else:
        return l

tdf['padded_domains'] = tdf.apply(lambda x: pad_domains(x.domain_name.split("|"), unique_domains), axis=1)

# %%
(tdf
 .sort_values('n_domains', ascending=False)
 .drop('machine_id', axis=1)
).head(5)
# Out:
#        week                                        domain_name  n_domains  \
# 24571    10  nordstromrack.com|amazon.com|expedia.com|ebay....          8
# 40382    12  avis.com|amazon.com|budget.com|expedia.com|orb...          7
# 22464     1  southwest.com|nordstrom.com|bestwestern.com|hy...          7
# 22470     7  bestbuy.com|nordstromrack.com|amazon.com|dicks...          6
# 13162     1  carters.com|amazon.com|gap.com|sephora.com|6pm...          6
#
#                                           padded_domains
# 24571  [nordstromrack.com, amazon.com, expedia.com, e...
# 40382  [avis.com, amazon.com, budget.com, expedia.com...
# 22464  [southwest.com, nordstrom.com, bestwestern.com...
# 22470  [bestbuy.com, nordstromrack.com, amazon.com, d...
# 13162  [carters.com, amazon.com, gap.com, sephora.com...

# %% [markdown]
# ### Apply simhash
#
# Using steps from https://github.com/shigeki/floc_simulator/blob/292fe1beb8a827f27a96dc951345a5c1cfb8da56/demos/floc_sample/main.go
#
# ```
# var kMaxNumberOfBitsInFloc uint8 = 50
# sim_hash := floc.SimHashString(domain_list, kMaxNumberOfBitsInFloc)
# ```

# %%
kMaxNumberOfBitsInFloc = 50
floc.hashes.sim_hash_string
# Out:
# <function floc.hashes.sim_hash_string(domains: List[str], k_max_numbers_of_bits_in_floc: int = 50) -> int>

# %%
tdf['simhash'] = tdf.padded_domains.apply(floc.hashes.sim_hash_string)
(tdf
 .sort_values('simhash', ascending=False)
 .drop(['machine_id', 'week'], axis=1)
).head(5)
# Out:
#          domain_name  n_domains  \
# 9730     walmart.com          1
# 15366    walmart.com          1
# 37462     amazon.com          1
# 14         alamo.com          1
# 6382   southwest.com          1
#
#                                           padded_domains           simhash
# 9730   [walmart.com, rei.com, potterybarn.com, alamo....  1125844243882986
# 15366  [walmart.com, fragrancenet.com, cheaptickets.c...  1125844220817417
# 37462  [amazon.com, dickssportinggoods.com, walmart.c...  1125613187633746
# 14     [alamo.com, aa.com, weightwatchers.com, llbean...  1125150976982634
# 6382   [southwest.com, vitacost.com, safeway.com, liv...  1124991270365285

# %% [markdown]
# Assign cohort IDs by applying the prefixLSH algorithm on all of the eligible machines in the panel.
#
# Note: In the browser implementation, the sorting has already been done and the browser has a clusters data file. The browser then queries for the specific cohort ID for a machine based on this clusters data.
#
# This is necessary for the real-world deployment.
#
# The clusters data file is not necessary for this analysis.
#
# Here we do the sorting and assignment together.

# %%
import prefixLSH

# %%
def binary_hash(h):
    return np.binary_repr(h, width=kMaxNumberOfBitsInFloc)

# %%
simhashes = tdf['simhash']
print(np.binary_repr(simhashes[0]))
print(len(np.binary_repr(simhashes[0])))

# some sanity checks

# check that all simhashes have binary representation less than 50 bits
for _i, simhash in enumerate(simhashes):
    assert(len(np.binary_repr(simhash)) <= 50)
    
# check that the ordering of the simhashes is the same for binary
# actually this will only work when we pad the higher bits with zeros
# as in the binary_hash implementation
sorted_simhashes = sorted(simhashes)
for i in range(1, len(simhashes)):
    assert(binary_hash(sorted_simhashes[i-1]) <= binary_hash(sorted_simhashes[i]))
    assert(sorted_simhashes[i-1] <= sorted_simhashes[i])
    
# sorted_simhashes
# Out:
# 10011100100011110111010111000100001010100000011100
# 50

# %% [markdown]
# Get a mapping from the simhashes to their cohorts, where this is determined by sorting all of the simhashes with prefixLSH.

# %%
cohorts_dict = prefixLSH.get_cohorts_dict(tdf['simhash'])
tdf["cohort"] = tdf['simhash'].map(cohorts_dict)

print("%s cohorts" % tdf["cohort"].nunique())
assert(tdf["cohort"].max() == tdf["cohort"].nunique())

print("%s samples (rows)" % len(tdf))
print("%0.1f avg samples per cohort" % (len(tdf)/tdf["cohort"].nunique()))

tdf.head()
# Out:
# 462 cohorts
# 43880 samples (rows)
# 95.0 avg samples per cohort
#    machine_id  week                   domain_name  n_domains  \
# 0    46569906     8                    amazon.com          1
# 1    46569906    12  nordstromrack.com|amazon.com          2
# 2    70298839    12                      ebay.com          1
# 3   100607252    11                   dominos.com          1
# 4   119721244     8                    amazon.com          1
#
#                                       padded_domains          simhash  cohort
# 0  [amazon.com, collectionsetc.com, abebooks.com,...  688559880185884     348
# 1  [nordstromrack.com, amazon.com, epson.com, int...  486253574150366     280
# 2  [ebay.com, carters.com, kohls.com, ticketmaste...   45097856270790      29
# 3  [dominos.com, finishline.com, nike.com, travel...  667142577893807     343
# 4  [amazon.com, sears.com, audible.com, petco.com...  185520311225340     133

# %%
fig,ax = plt.subplots(1,1,figsize=(4,2), dpi=100)
tdf["cohort"].value_counts().hist(ax=ax)
plt.ylabel("cohorts")
plt.xlabel("cohort size")

tdf["cohort"].value_counts()
# Out:
# 98     237
# 452    233
# 335    228
# 218    215
# 224    211
#       ...
# 248     51
# 161     51
# 80      50
# 278     50
# 74      50
# Name: cohort, Length: 462, dtype: int64

# %% [markdown]
# ### Using random data
#
# TODO:
# assign random sets of domains to machines and check the relationship / distribution of cohort assignments and demographics.

# %% [markdown]
# ### Using sessions data

# %% [markdown]
# #### Load in preprocessed sessions data

# %%
weeks_machines_domains_fpath = '../output/weeks_machines_domains.csv'
    
def read_weeks_machines_domains(nrows=None):
    """
    Reads csv mapping machine_id, week to domains.
    Returns data frame with columns:
    machine_id, week, n_domains, domains
    where domains is a list
    """
    print('reading from %s...' % weeks_machines_domains_fpath)
    df = pd.read_csv(weeks_machines_domains_fpath, nrows=nrows)
    df['domains'] = df.fillna('').domains_str.apply(lambda x: x.split('|'))
    df.drop('domains_str', axis=1, inplace=True)
    print('... read %s rows' % len(df))
    return df

# %%
weeks_machines_domains_df = read_weeks_machines_domains()
# Out:
# reading from ../output/weeks_machines_domains.csv...
# ... read 4877236 rows

# %%
print(len(weeks_machines_domains_df))
weeks_machines_domains_df.drop('machine_id', axis=1).head()
# Out:
# 4877236
#    week  n_domains                                            domains
# 0     1        119  [homeworkmarket.com, shareably.net, crschools....
# 1     1          0                                                 []
# 2     1          2                        [nbcsports.com, google.com]
# 3     1          5  [signaturesalon.us, tasteofhome.com, facebook....
# 4     1          8  [myway.com, victoryoutreach.org, adobeconnect....

# %%
n_domains_threshold = 7

# %% [markdown]
# ### PROBLEM to fix
#
# TLDR;
#
# There are many domains in the domains lists that are not valid eTLD+1's. They are instead just suffixes that can look like eTLD+1's (e.g. blogspot.com).
#
# This causes the simhash function to throw an error.
#
# These domains must be removed.
#
#
# ###### Notes
#
#
# Error thrown when applying sim_hash_string we keep getting an error at
#
# https://github.com/thepabloaguilar/floc/blob/b5d6b0b5e53f660175b5fa4ca3acb45fec403b53/floc_simulator/main.go#L44
#
#
# where the error says that a domain in the domains list is not a proper eTLD+1
# ```
# "publicsuffix: cannot derive eTLD+1 for domain "blogspot.com"
# ```
#
# For example, `blogspot.com` is in this list: https://publicsuffix.org/list/public_suffix_list.dat
#
# And this list is used by the go package that determines whether the domain is eTLD+1: https://pkg.go.dev/golang.org/x/net/publicsuffix
#
# The part of the publicSuffixList implementation that causes the error is here:
# ```
# eTLDPlusOne, err := publicsuffix.EffectiveTLDPlusOne(host)
# ```
# -->
# https://cs.opensource.google/go/x/net/+/d83791d6:publicsuffix/list.go;l=167

# %%
domains_set = set()
for i, domains in weeks_machines_domains_df['domains'].items():
    if i % 100000 == 0:
        print('%s/%s' % (i, len(weeks_machines_domains_df['domains'])))
    domains_set.update(set(domains))
# Out:
# 0/4877236
# 100000/4877236
# 200000/4877236
# 300000/4877236
# 400000/4877236
# 500000/4877236
# 600000/4877236
# 700000/4877236
# 800000/4877236
# 900000/4877236
# 1000000/4877236
# 1100000/4877236
# 1200000/4877236
# 1300000/4877236
# 1400000/4877236
# 1500000/4877236
# 1600000/4877236
# 1700000/4877236
# 1800000/4877236
# 1900000/4877236
# 2000000/4877236
# 2100000/4877236
# 2200000/4877236
# 2300000/4877236
# 2400000/4877236
# 2500000/4877236
# 2600000/4877236
# 2700000/4877236
# 2800000/4877236
# 2900000/4877236
# 3000000/4877236
# 3100000/4877236
# 3200000/4877236
# 3300000/4877236
# 3400000/4877236
# 3500000/4877236
# 3600000/4877236
# 3700000/4877236
# 3800000/4877236
# 3900000/4877236
# 4000000/4877236
# 4100000/4877236
# 4200000/4877236
# 4300000/4877236
# 4400000/4877236
# 4500000/4877236
# 4600000/4877236
# 4700000/4877236
# 4800000/4877236

# %%
print('%s unique domains' % len(domains_set))
# Out:
# 4352338 unique domains

# %% [markdown]
# Collect the bad domains.

# %%
def get_bad_domains(domains):
    """
    Returns list of 'bad' domains.
    Where 'bad' domains are those where the floc simhash function throws an error
    because the domains are not eTLD+1's.
    """
    bad_domains_set = set()
    for i, d in enumerate(domains):
        if i % 10000 == 0:
            print('%s/%s' % (i, len(domains)))
        try:
            floc.hashes.sim_hash_string([d])
        except Exception as e:
            print(str(e))
            bad_domains_set.add(d)
    return bad_domains_set

# %%
bad_domains = get_bad_domains(domains_set)
print('%s bad domains' % len(bad_domains))
bad_domains
# Out:
# 0/4352338
# publicsuffix: cannot derive eTLD+1 for domain ""
# publicsuffix: cannot derive eTLD+1 for domain "web.tr"
# publicsuffix: cannot derive eTLD+1 for domain "podlasie.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gov.pr"
# publicsuffix: cannot derive eTLD+1 for domain "rec.br"
# publicsuffix: cannot derive eTLD+1 for domain "k12.ne.us"
# publicsuffix: cannot derive eTLD+1 for domain "edu.om"
# 10000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "mil.uy"
# publicsuffix: cannot derive eTLD+1 for domain "edu.cn"
# 20000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "mil.ph"
# publicsuffix: cannot derive eTLD+1 for domain "homeunix.com"
# publicsuffix: cannot derive eTLD+1 for domain "gov.qa"
# 30000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.az"
# publicsuffix: cannot derive eTLD+1 for domain "gov.zm"
# 40000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "me.us"
# publicsuffix: cannot derive eTLD+1 for domain "en.it"
# publicsuffix: cannot derive eTLD+1 for domain "nsw.au"
# 50000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.bd"
# publicsuffix: cannot derive eTLD+1 for domain "london.museum"
# publicsuffix: cannot derive eTLD+1 for domain "elk.pl"
# publicsuffix: cannot derive eTLD+1 for domain "servecounterstrike.com"
# publicsuffix: cannot derive eTLD+1 for domain "fukuoka.jp"
# 60000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "no-ip.info"
# publicsuffix: cannot derive eTLD+1 for domain "rel.pl"
# publicsuffix: cannot derive eTLD+1 for domain "lc.it"
# 70000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "teramo.it"
# publicsuffix: cannot derive eTLD+1 for domain "gov.lk"
# publicsuffix: cannot derive eTLD+1 for domain "web.ve"
# publicsuffix: cannot derive eTLD+1 for domain "v.bg"
# publicsuffix: cannot derive eTLD+1 for domain "to.it"
# publicsuffix: cannot derive eTLD+1 for domain "wielun.pl"
# 80000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.bi"
# publicsuffix: cannot derive eTLD+1 for domain "shimane.jp"
# 90000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "int.mw"
# publicsuffix: cannot derive eTLD+1 for domain "swidnik.pl"
# publicsuffix: cannot derive eTLD+1 for domain "mil.id"
# 100000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "vercelli.it"
# publicsuffix: cannot derive eTLD+1 for domain "gob.ec"
# 110000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ns.ca"
# publicsuffix: cannot derive eTLD+1 for domain "br.com"
# publicsuffix: cannot derive eTLD+1 for domain "na.it"
# 120000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "cistron.nl"
# publicsuffix: cannot derive eTLD+1 for domain "gov.vc"
# 130000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.bf"
# publicsuffix: cannot derive eTLD+1 for domain "ud.it"
# publicsuffix: cannot derive eTLD+1 for domain "mn.it"
# publicsuffix: cannot derive eTLD+1 for domain "mb.it"
# 140000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.bg"
# publicsuffix: cannot derive eTLD+1 for domain "geek.nz"
# publicsuffix: cannot derive eTLD+1 for domain "edu.mv"
# publicsuffix: cannot derive eTLD+1 for domain "lubin.pl"
# publicsuffix: cannot derive eTLD+1 for domain "de.com"
# publicsuffix: cannot derive eTLD+1 for domain "radio.fm"
# 150000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "rimini.it"
# publicsuffix: cannot derive eTLD+1 for domain "te.ua"
# publicsuffix: cannot derive eTLD+1 for domain "ab.ca"
# 160000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "homeunix.net"
# publicsuffix: cannot derive eTLD+1 for domain "museum.no"
# publicsuffix: cannot derive eTLD+1 for domain "ddnss.org"
# 170000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.zw"
# publicsuffix: cannot derive eTLD+1 for domain "i.ng"
# publicsuffix: cannot derive eTLD+1 for domain "drammen.no"
# publicsuffix: cannot derive eTLD+1 for domain "mil.ae"
# publicsuffix: cannot derive eTLD+1 for domain "gov.tr"
# publicsuffix: cannot derive eTLD+1 for domain "ppg.br"
# publicsuffix: cannot derive eTLD+1 for domain "vinnica.ua"
# 180000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "webredirect.org"
# publicsuffix: cannot derive eTLD+1 for domain "ibaraki.jp"
# publicsuffix: cannot derive eTLD+1 for domain "vt.us"
# publicsuffix: cannot derive eTLD+1 for domain "sa.it"
# publicsuffix: cannot derive eTLD+1 for domain "gniezno.pl"
# 190000/4352338
# 200000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "lg.ua"
# publicsuffix: cannot derive eTLD+1 for domain "bel.tr"
# 210000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "walbrzych.pl"
# publicsuffix: cannot derive eTLD+1 for domain "pr.it"
# publicsuffix: cannot derive eTLD+1 for domain "lt.ua"
# 220000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "me.uk"
# publicsuffix: cannot derive eTLD+1 for domain "atm.pl"
# publicsuffix: cannot derive eTLD+1 for domain "withgoogle.com"
# publicsuffix: cannot derive eTLD+1 for domain "eng.br"
# 230000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "rawa-maz.pl"
# 240000/4352338
# 250000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "fukushima.jp"
# publicsuffix: cannot derive eTLD+1 for domain "campania.it"
# publicsuffix: cannot derive eTLD+1 for domain "mil.kh"
# publicsuffix: cannot derive eTLD+1 for domain "def.br"
# publicsuffix: cannot derive eTLD+1 for domain "firenze.it"
# publicsuffix: cannot derive eTLD+1 for domain "press.ma"
# publicsuffix: cannot derive eTLD+1 for domain "bydgoszcz.pl"
# publicsuffix: cannot derive eTLD+1 for domain "ca.us"
# 260000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "sytes.net"
# publicsuffix: cannot derive eTLD+1 for domain "aviation.museum"
# publicsuffix: cannot derive eTLD+1 for domain "square7.ch"
# publicsuffix: cannot derive eTLD+1 for domain "cn.ua"
# 270000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "sp.it"
# 280000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "al.us"
# 290000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gen.nz"
# publicsuffix: cannot derive eTLD+1 for domain "priv.pl"
# publicsuffix: cannot derive eTLD+1 for domain "pe.ca"
# 300000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "nu.ca"
# publicsuffix: cannot derive eTLD+1 for domain "roma.it"
# publicsuffix: cannot derive eTLD+1 for domain "homeip.net"
# publicsuffix: cannot derive eTLD+1 for domain "readthedocs.io"
# 310000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "nov.su"
# publicsuffix: cannot derive eTLD+1 for domain "lu.it"
# 320000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "kanagawa.jp"
# publicsuffix: cannot derive eTLD+1 for domain "gouv.bj"
# publicsuffix: cannot derive eTLD+1 for domain "gdynia.pl"
# 330000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "vn.ua"
# publicsuffix: cannot derive eTLD+1 for domain "africa.com"
# 340000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.mw"
# publicsuffix: cannot derive eTLD+1 for domain "gov.cy"
# publicsuffix: cannot derive eTLD+1 for domain "edu.bb"
# 350000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "og.ao"
# publicsuffix: cannot derive eTLD+1 for domain "gob.ve"
# publicsuffix: cannot derive eTLD+1 for domain "leadpages.co"
# 360000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "vladimir.ru"
# publicsuffix: cannot derive eTLD+1 for domain "edu.bo"
# publicsuffix: cannot derive eTLD+1 for domain "med.br"
# publicsuffix: cannot derive eTLD+1 for domain "mil.ar"
# 370000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.zm"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.co.id"
# publicsuffix: cannot derive eTLD+1 for domain "starachowice.pl"
# publicsuffix: cannot derive eTLD+1 for domain "asn.au"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.com.tr"
# publicsuffix: cannot derive eTLD+1 for domain "novara.it"
# 380000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "mil.br"
# 390000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "myfirewall.org"
# 400000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "dyndns-ip.com"
# publicsuffix: cannot derive eTLD+1 for domain "bloxcms.com"
# publicsuffix: cannot derive eTLD+1 for domain "sch.id"
# publicsuffix: cannot derive eTLD+1 for domain "edu.bs"
# publicsuffix: cannot derive eTLD+1 for domain "nd.us"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.fi"
# publicsuffix: cannot derive eTLD+1 for domain "edu.za"
# 410000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "leczna.pl"
# publicsuffix: cannot derive eTLD+1 for domain "nctu.me"
# publicsuffix: cannot derive eTLD+1 for domain "agro.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gov.tn"
# publicsuffix: cannot derive eTLD+1 for domain "jp.net"
# publicsuffix: cannot derive eTLD+1 for domain "ringsaker.no"
# 420000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "mi.th"
# 430000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.np"
# publicsuffix: cannot derive eTLD+1 for domain "id.au"
# 440000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "pulawy.pl"
# publicsuffix: cannot derive eTLD+1 for domain "noip.us"
# 450000/4352338
# 460000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ed.ao"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ph"
# publicsuffix: cannot derive eTLD+1 for domain "mil.kr"
# 470000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "lodi.it"
# publicsuffix: cannot derive eTLD+1 for domain "pesaro-urbino.it"
# publicsuffix: cannot derive eTLD+1 for domain "fl.us"
# publicsuffix: cannot derive eTLD+1 for domain "debian.net"
# publicsuffix: cannot derive eTLD+1 for domain "cuneo.it"
# 480000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.pl"
# publicsuffix: cannot derive eTLD+1 for domain "hepforge.org"
# publicsuffix: cannot derive eTLD+1 for domain "url.tw"
# publicsuffix: cannot derive eTLD+1 for domain "tokyo.jp"
# publicsuffix: cannot derive eTLD+1 for domain "mil.np"
# 490000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "md.us"
# publicsuffix: cannot derive eTLD+1 for domain "krasnik.pl"
# publicsuffix: cannot derive eTLD+1 for domain "elblag.pl"
# publicsuffix: cannot derive eTLD+1 for domain "flog.br"
# 500000/4352338
# 510000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gs.cn"
# publicsuffix: cannot derive eTLD+1 for domain "rnrt.tn"
# publicsuffix: cannot derive eTLD+1 for domain "maori.nz"
# publicsuffix: cannot derive eTLD+1 for domain "mil.ec"
# publicsuffix: cannot derive eTLD+1 for domain "lib.co.us"
# publicsuffix: cannot derive eTLD+1 for domain "kalisz.pl"
# publicsuffix: cannot derive eTLD+1 for domain "oita.jp"
# 520000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "lpages.co"
# publicsuffix: cannot derive eTLD+1 for domain "nieruchomosci.pl"
# publicsuffix: cannot derive eTLD+1 for domain "pg.it"
# 530000/4352338
# 540000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "mypsx.net"
# publicsuffix: cannot derive eTLD+1 for domain "info.hu"
# publicsuffix: cannot derive eTLD+1 for domain "shizuoka.jp"
# publicsuffix: cannot derive eTLD+1 for domain "bialystok.pl"
# publicsuffix: cannot derive eTLD+1 for domain "goip.de"
# publicsuffix: cannot derive eTLD+1 for domain "so.it"
# publicsuffix: cannot derive eTLD+1 for domain "gob.mx"
# 550000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "coal.museum"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.si"
# publicsuffix: cannot derive eTLD+1 for domain "gov.mg"
# publicsuffix: cannot derive eTLD+1 for domain "webhop.me"
# publicsuffix: cannot derive eTLD+1 for domain "pd.it"
# 560000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "powiat.pl"
# publicsuffix: cannot derive eTLD+1 for domain "edu.bn"
# publicsuffix: cannot derive eTLD+1 for domain "demon.nl"
# 570000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "lukow.pl"
# 580000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "bologna.it"
# publicsuffix: cannot derive eTLD+1 for domain "edu.ar"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.is"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.ru"
# publicsuffix: cannot derive eTLD+1 for domain "mt.us"
# 590000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "applinzi.com"
# 600000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ut.us"
# publicsuffix: cannot derive eTLD+1 for domain "mil.al"
# 610000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gda.pl"
# publicsuffix: cannot derive eTLD+1 for domain "kiev.ua"
# publicsuffix: cannot derive eTLD+1 for domain "miasta.pl"
# 620000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.bh"
# publicsuffix: cannot derive eTLD+1 for domain "database.museum"
# publicsuffix: cannot derive eTLD+1 for domain "ostroleka.pl"
# 630000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "nagano.jp"
# publicsuffix: cannot derive eTLD+1 for domain "azurewebsites.net"
# publicsuffix: cannot derive eTLD+1 for domain "servep2p.com"
# publicsuffix: cannot derive eTLD+1 for domain "limanowa.pl"
# publicsuffix: cannot derive eTLD+1 for domain "agrigento.it"
# 640000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gitlab.io"
# publicsuffix: cannot derive eTLD+1 for domain "bs.it"
# 650000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "hasura-app.io"
# publicsuffix: cannot derive eTLD+1 for domain "snasa.no"
# 660000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.cm"
# 670000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ch.it"
# publicsuffix: cannot derive eTLD+1 for domain "mi.it"
# publicsuffix: cannot derive eTLD+1 for domain "nysa.pl"
# publicsuffix: cannot derive eTLD+1 for domain "edu.mt"
# 680000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.bn"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.com.eg"
# publicsuffix: cannot derive eTLD+1 for domain "nom.uy"
# publicsuffix: cannot derive eTLD+1 for domain "ln.cn"
# 690000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "synology-diskstation.de"
# publicsuffix: cannot derive eTLD+1 for domain "gov.dm"
# publicsuffix: cannot derive eTLD+1 for domain "homelinux.com"
# 700000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "arezzo.it"
# publicsuffix: cannot derive eTLD+1 for domain "friuliveneziagiulia.it"
# publicsuffix: cannot derive eTLD+1 for domain "edu.lb"
# publicsuffix: cannot derive eTLD+1 for domain "ddns.net"
# publicsuffix: cannot derive eTLD+1 for domain "art.br"
# publicsuffix: cannot derive eTLD+1 for domain "przeworsk.pl"
# publicsuffix: cannot derive eTLD+1 for domain "mex.com"
# 710000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.bb"
# 720000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "eu.org"
# publicsuffix: cannot derive eTLD+1 for domain "homedns.org"
# 730000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "rc.it"
# publicsuffix: cannot derive eTLD+1 for domain "remotewd.com"
# 740000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "utazas.hu"
# publicsuffix: cannot derive eTLD+1 for domain "from-ok.com"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.fr"
# 750000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.bz"
# 760000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.bt"
# publicsuffix: cannot derive eTLD+1 for domain "gub.uy"
# publicsuffix: cannot derive eTLD+1 for domain "catania.it"
# publicsuffix: cannot derive eTLD+1 for domain "edu.kg"
# 770000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "wlocl.pl"
# publicsuffix: cannot derive eTLD+1 for domain "serveftp.com"
# 780000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "travel.pl"
# publicsuffix: cannot derive eTLD+1 for domain "edu.ht"
# publicsuffix: cannot derive eTLD+1 for domain "lpusercontent.com"
# publicsuffix: cannot derive eTLD+1 for domain "hi.us"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.li"
# 790000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.ph"
# publicsuffix: cannot derive eTLD+1 for domain "in.rs"
# 800000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "lima-city.de"
# 810000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "web.id"
# publicsuffix: cannot derive eTLD+1 for domain "pesarourbino.it"
# 820000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ah.cn"
# publicsuffix: cannot derive eTLD+1 for domain "altervista.org"
# publicsuffix: cannot derive eTLD+1 for domain "gov.rs"
# 830000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "nom.es"
# publicsuffix: cannot derive eTLD+1 for domain "tn.us"
# 840000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "cv.ua"
# publicsuffix: cannot derive eTLD+1 for domain "servemp3.com"
# publicsuffix: cannot derive eTLD+1 for domain "la.us"
# publicsuffix: cannot derive eTLD+1 for domain "sd.us"
# 850000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "lomza.pl"
# publicsuffix: cannot derive eTLD+1 for domain "ro.im"
# publicsuffix: cannot derive eTLD+1 for domain "agr.br"
# publicsuffix: cannot derive eTLD+1 for domain "servebbs.com"
# publicsuffix: cannot derive eTLD+1 for domain "nara.jp"
# 860000/4352338
# 870000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.krd"
# publicsuffix: cannot derive eTLD+1 for domain "gov.gd"
# publicsuffix: cannot derive eTLD+1 for domain "kharkiv.ua"
# 880000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "media.pl"
# publicsuffix: cannot derive eTLD+1 for domain "k12.tr"
# publicsuffix: cannot derive eTLD+1 for domain "yn.cn"
# 890000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "fg.it"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.de"
# publicsuffix: cannot derive eTLD+1 for domain "freedesktop.org"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ac"
# publicsuffix: cannot derive eTLD+1 for domain "gov.sh"
# 900000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ponpes.id"
# publicsuffix: cannot derive eTLD+1 for domain "info.na"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ps"
# 910000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "selfip.net"
# publicsuffix: cannot derive eTLD+1 for domain "if.ua"
# publicsuffix: cannot derive eTLD+1 for domain "med.ec"
# 920000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "hitra.no"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.be"
# publicsuffix: cannot derive eTLD+1 for domain "saotome.st"
# publicsuffix: cannot derive eTLD+1 for domain "lowicz.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ie"
# 930000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.gr"
# publicsuffix: cannot derive eTLD+1 for domain "nh.us"
# 940000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "myvnc.com"
# 950000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "art.pl"
# 960000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "rv.ua"
# publicsuffix: cannot derive eTLD+1 for domain "perugia.it"
# publicsuffix: cannot derive eTLD+1 for domain "veneto.it"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.am"
# publicsuffix: cannot derive eTLD+1 for domain "karpacz.pl"
# publicsuffix: cannot derive eTLD+1 for domain "sc.ke"
# 970000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "dnsiskinky.com"
# publicsuffix: cannot derive eTLD+1 for domain "gov.cl"
# publicsuffix: cannot derive eTLD+1 for domain "opoczno.pl"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.co.il"
# 980000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "olecko.pl"
# publicsuffix: cannot derive eTLD+1 for domain "poniatowa.pl"
# publicsuffix: cannot derive eTLD+1 for domain "firm.in"
# publicsuffix: cannot derive eTLD+1 for domain "mazowsze.pl"
# 990000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.fj"
# publicsuffix: cannot derive eTLD+1 for domain "soundcast.me"
# publicsuffix: cannot derive eTLD+1 for domain "clan.rip"
# publicsuffix: cannot derive eTLD+1 for domain "mb.ca"
# 1000000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "webhop.biz"
# publicsuffix: cannot derive eTLD+1 for domain "savona.it"
# publicsuffix: cannot derive eTLD+1 for domain "avocat.fr"
# publicsuffix: cannot derive eTLD+1 for domain "calabria.it"
# publicsuffix: cannot derive eTLD+1 for domain "gc.ca"
# publicsuffix: cannot derive eTLD+1 for domain "ve.it"
# 1010000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "art.museum"
# publicsuffix: cannot derive eTLD+1 for domain "ms.kr"
# 1020000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "experts-comptables.fr"
# publicsuffix: cannot derive eTLD+1 for domain "parliament.cy"
# 1030000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "fi.it"
# publicsuffix: cannot derive eTLD+1 for domain "tur.ar"
# 1040000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "nc.us"
# publicsuffix: cannot derive eTLD+1 for domain "ar.it"
# 1050000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.pk"
# publicsuffix: cannot derive eTLD+1 for domain "edu.rs"
# 1060000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "synology-ds.de"
# 1070000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "pri.ee"
# publicsuffix: cannot derive eTLD+1 for domain "pomorskie.pl"
# publicsuffix: cannot derive eTLD+1 for domain "myhome-server.de"
# publicsuffix: cannot derive eTLD+1 for domain "cremona.it"
# 1080000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "withyoutube.com"
# publicsuffix: cannot derive eTLD+1 for domain "gov.sy"
# publicsuffix: cannot derive eTLD+1 for domain "zgorzelec.pl"
# publicsuffix: cannot derive eTLD+1 for domain "go.jp"
# 1090000/4352338
# 1100000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ddnsgeek.com"
# publicsuffix: cannot derive eTLD+1 for domain "dyndns-remote.com"
# 1110000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "thruhere.net"
# publicsuffix: cannot derive eTLD+1 for domain "beep.pl"
# publicsuffix: cannot derive eTLD+1 for domain "bolt.hu"
# publicsuffix: cannot derive eTLD+1 for domain "ven.it"
# 1120000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "school.nz"
# publicsuffix: cannot derive eTLD+1 for domain "olkusz.pl"
# publicsuffix: cannot derive eTLD+1 for domain "my-router.de"
# 1130000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "y"
# 1140000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "pp.ua"
# publicsuffix: cannot derive eTLD+1 for domain "jelenia-gora.pl"
# 1150000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "synology.me"
# publicsuffix: cannot derive eTLD+1 for domain "aq.it"
# publicsuffix: cannot derive eTLD+1 for domain "tm.pl"
# publicsuffix: cannot derive eTLD+1 for domain "youtube.ck"
# publicsuffix: cannot derive eTLD+1 for domain "nl.ca"
# 1160000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.iq"
# publicsuffix: cannot derive eTLD+1 for domain "az.us"
# publicsuffix: cannot derive eTLD+1 for domain "bytom.pl"
# 1170000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "laspezia.it"
# 1180000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "siracusa.it"
# publicsuffix: cannot derive eTLD+1 for domain "mywire.org"
# publicsuffix: cannot derive eTLD+1 for domain "gov.scot"
# publicsuffix: cannot derive eTLD+1 for domain "idf.il"
# 1190000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "za.org"
# publicsuffix: cannot derive eTLD+1 for domain "no.it"
# 1200000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "abruzzo.it"
# publicsuffix: cannot derive eTLD+1 for domain "chambagri.fr"
# 1210000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.cz"
# 1220000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.gi"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ls"
# publicsuffix: cannot derive eTLD+1 for domain "sinaapp.com"
# publicsuffix: cannot derive eTLD+1 for domain "cri.nz"
# 1230000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "law.pro"
# publicsuffix: cannot derive eTLD+1 for domain "kr.ua"
# 1240000/4352338
# publicsuffix: empty label in domain "in."
# publicsuffix: cannot derive eTLD+1 for domain "is-slick.com"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ua"
# 1250000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.gy"
# publicsuffix: cannot derive eTLD+1 for domain "kagawa.jp"
# publicsuffix: cannot derive eTLD+1 for domain "webhop.net"
# publicsuffix: cannot derive eTLD+1 for domain "za.net"
# 1260000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.in"
# publicsuffix: cannot derive eTLD+1 for domain "vicenza.it"
# publicsuffix: cannot derive eTLD+1 for domain "asso.fr"
# 1270000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "game-host.org"
# publicsuffix: cannot derive eTLD+1 for domain "3utilities.com"
# publicsuffix: cannot derive eTLD+1 for domain "ct.it"
# 1280000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ct.us"
# publicsuffix: cannot derive eTLD+1 for domain "sch.ng"
# publicsuffix: cannot derive eTLD+1 for domain "knightpoint.systems"
# 1290000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "google.ck"
# publicsuffix: cannot derive eTLD+1 for domain "yolasite.com"
# publicsuffix: cannot derive eTLD+1 for domain "gov.om"
# publicsuffix: cannot derive eTLD+1 for domain "gov.sb"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ar"
# 1300000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.hu"
# publicsuffix: cannot derive eTLD+1 for domain "k12.co.us"
# 1310000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.sl"
# publicsuffix: cannot derive eTLD+1 for domain "foggia.it"
# publicsuffix: cannot derive eTLD+1 for domain "mil.gh"
# 1320000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "meteorapp.com"
# publicsuffix: cannot derive eTLD+1 for domain "cscheater.er"
# publicsuffix: cannot derive eTLD+1 for domain "gov.bs"
# publicsuffix: cannot derive eTLD+1 for domain "ap.it"
# 1330000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "info.ro"
# 1340000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "go.it"
# publicsuffix: cannot derive eTLD+1 for domain "nom.al"
# publicsuffix: cannot derive eTLD+1 for domain "cloudfunctions.net"
# publicsuffix: cannot derive eTLD+1 for domain "swidnica.pl"
# publicsuffix: cannot derive eTLD+1 for domain "uz.ua"
# 1350000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "wroclaw.pl"
# 1360000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.jp"
# publicsuffix: cannot derive eTLD+1 for domain "gov.sc"
# 1370000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ath.cx"
# 1380000/4352338
# 1390000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "nsn.us"
# publicsuffix: cannot derive eTLD+1 for domain "jgora.pl"
# publicsuffix: cannot derive eTLD+1 for domain "pointto.us"
# publicsuffix: cannot derive eTLD+1 for domain "inf.br"
# publicsuffix: cannot derive eTLD+1 for domain "gb.net"
# 1400000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "grosseto.it"
# publicsuffix: cannot derive eTLD+1 for domain "cr.it"
# 1410000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "czeladz.pl"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.nl"
# 1420000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.bm"
# publicsuffix: cannot derive eTLD+1 for domain "malbork.pl"
# 1430000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "udine.it"
# 1440000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.au"
# publicsuffix: cannot derive eTLD+1 for domain "biz.mm"
# publicsuffix: cannot derive eTLD+1 for domain "sch.ir"
# publicsuffix: cannot derive eTLD+1 for domain "palermo.it"
# 1450000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.mo"
# publicsuffix: cannot derive eTLD+1 for domain "gov.rw"
# publicsuffix: cannot derive eTLD+1 for domain "radio.am"
# 1460000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ny.us"
# publicsuffix: cannot derive eTLD+1 for domain "workisboring.com"
# publicsuffix: cannot derive eTLD+1 for domain "edu.sa"
# 1470000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "tozsde.hu"
# publicsuffix: cannot derive eTLD+1 for domain "bbs.tr"
# publicsuffix: cannot derive eTLD+1 for domain "dnsalias.org"
# publicsuffix: cannot derive eTLD+1 for domain "od.ua"
# 1480000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ga.us"
# 1490000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "lucca.it"
# publicsuffix: cannot derive eTLD+1 for domain "gov.it"
# 1500000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "bo.it"
# publicsuffix: cannot derive eTLD+1 for domain "wiki.br"
# publicsuffix: cannot derive eTLD+1 for domain "gouv.ml"
# publicsuffix: cannot derive eTLD+1 for domain "pc.pl"
# 1510000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ed.jp"
# 1520000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.ba"
# publicsuffix: cannot derive eTLD+1 for domain "gen.tr"
# 1530000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "health.vn"
# 1540000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.ae"
# publicsuffix: cannot derive eTLD+1 for domain "ae.org"
# publicsuffix: cannot derive eTLD+1 for domain "liguria.it"
# publicsuffix: cannot derive eTLD+1 for domain "eu.int"
# publicsuffix: cannot derive eTLD+1 for domain "in-berlin.de"
# 1550000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "vb.it"
# publicsuffix: cannot derive eTLD+1 for domain "blog.br"
# publicsuffix: cannot derive eTLD+1 for domain "pantheonsite.io"
# publicsuffix: cannot derive eTLD+1 for domain "eng.pro"
# publicsuffix: cannot derive eTLD+1 for domain "edu.lc"
# 1560000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "tn.it"
# publicsuffix: cannot derive eTLD+1 for domain "edu.kw"
# 1570000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "si.it"
# publicsuffix: cannot derive eTLD+1 for domain "hyogo.jp"
# publicsuffix: cannot derive eTLD+1 for domain "radom.pl"
# publicsuffix: cannot derive eTLD+1 for domain "edu.pt"
# 1580000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "bari.it"
# publicsuffix: cannot derive eTLD+1 for domain "gov.al"
# publicsuffix: cannot derive eTLD+1 for domain "edu.tw"
# publicsuffix: cannot derive eTLD+1 for domain "64-b.it"
# 1590000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "biz.pk"
# publicsuffix: cannot derive eTLD+1 for domain "sc.ug"
# 1600000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "slask.pl"
# 1610000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "de.us"
# publicsuffix: cannot derive eTLD+1 for domain "ce.it"
# 1620000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "psi.br"
# publicsuffix: cannot derive eTLD+1 for domain "mie.jp"
# publicsuffix: cannot derive eTLD+1 for domain "sondrio.it"
# publicsuffix: cannot derive eTLD+1 for domain "jpn.com"
# 1630000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "kumamoto.jp"
# publicsuffix: cannot derive eTLD+1 for domain "duckdns.org"
# publicsuffix: cannot derive eTLD+1 for domain "edu.ru"
# 1640000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "we.bs"
# publicsuffix: cannot derive eTLD+1 for domain "msk.su"
# publicsuffix: cannot derive eTLD+1 for domain "go.ke"
# publicsuffix: cannot derive eTLD+1 for domain "in.th"
# 1650000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "uni5.net"
# publicsuffix: cannot derive eTLD+1 for domain "edu.ge"
# publicsuffix: cannot derive eTLD+1 for domain "id.us"
# publicsuffix: cannot derive eTLD+1 for domain "tychy.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gov.af"
# 1660000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "square7.de"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ki"
# publicsuffix: cannot derive eTLD+1 for domain "info.ve"
# 1670000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "vgs.no"
# publicsuffix: cannot derive eTLD+1 for domain "aichi.jp"
# publicsuffix: cannot derive eTLD+1 for domain "jdevcloud.com"
# 1680000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "info.pl"
# publicsuffix: cannot derive eTLD+1 for domain "sebastopol.ua"
# publicsuffix: cannot derive eTLD+1 for domain "ra.it"
# publicsuffix: cannot derive eTLD+1 for domain "fvg.it"
# 1690000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "targi.pl"
# 1700000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "sc.us"
# 1710000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.sg"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.co.at"
# 1720000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "on-aptible.com"
# publicsuffix: cannot derive eTLD+1 for domain "no.com"
# publicsuffix: cannot derive eTLD+1 for domain "ro.it"
# publicsuffix: cannot derive eTLD+1 for domain "gov.jm"
# publicsuffix: cannot derive eTLD+1 for domain "tv.tr"
# 1730000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "medecin.fr"
# publicsuffix: cannot derive eTLD+1 for domain "sr.it"
# publicsuffix: cannot derive eTLD+1 for domain "serveirc.com"
# 1740000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "eco.br"
# publicsuffix: cannot derive eTLD+1 for domain "skoczow.pl"
# publicsuffix: cannot derive eTLD+1 for domain "web.za"
# 1750000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "go.ug"
# publicsuffix: cannot derive eTLD+1 for domain "homelinux.org"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.com.au"
# publicsuffix: cannot derive eTLD+1 for domain "mazury.pl"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.ug"
# publicsuffix: cannot derive eTLD+1 for domain "fr.it"
# publicsuffix: cannot derive eTLD+1 for domain "edu.gt"
# 1760000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "brasilia.me"
# 1770000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "k12.or.us"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ws"
# 1780000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "turystyka.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gotdns.ch"
# publicsuffix: cannot derive eTLD+1 for domain "warszawa.pl"
# publicsuffix: cannot derive eTLD+1 for domain "edu.la"
# publicsuffix: cannot derive eTLD+1 for domain "gov.by"
# publicsuffix: cannot derive eTLD+1 for domain "go.th"
# publicsuffix: cannot derive eTLD+1 for domain "qc.ca"
# 1790000/4352338
# publicsuffix: empty label in domain "question."
# publicsuffix: cannot derive eTLD+1 for domain "kaszuby.pl"
# publicsuffix: cannot derive eTLD+1 for domain "dyndns-at-work.com"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ng"
# 1800000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "eu.com"
# publicsuffix: cannot derive eTLD+1 for domain "tv.it"
# publicsuffix: cannot derive eTLD+1 for domain "fi.cr"
# publicsuffix: cannot derive eTLD+1 for domain "prato.it"
# publicsuffix: cannot derive eTLD+1 for domain "bedzin.pl"
# 1810000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.sg"
# publicsuffix: cannot derive eTLD+1 for domain "pro.br"
# publicsuffix: cannot derive eTLD+1 for domain "al.it"
# publicsuffix: cannot derive eTLD+1 for domain "nom.co"
# publicsuffix: cannot derive eTLD+1 for domain "il.us"
# 1820000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "wolomin.pl"
# publicsuffix: cannot derive eTLD+1 for domain "cnt.br"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.ca"
# publicsuffix: cannot derive eTLD+1 for domain "virtual.museum"
# 1830000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "nikolaev.ua"
# 1840000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "eating-organic.net"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.qa"
# publicsuffix: cannot derive eTLD+1 for domain "gov.to"
# 1850000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "pa.it"
# 1860000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "club.tw"
# publicsuffix: cannot derive eTLD+1 for domain "cherkassy.ua"
# publicsuffix: cannot derive eTLD+1 for domain "gliwice.pl"
# publicsuffix: cannot derive eTLD+1 for domain "dyn-o-saur.com"
# publicsuffix: cannot derive eTLD+1 for domain "edu.af"
# publicsuffix: cannot derive eTLD+1 for domain "dyn-vpn.de"
# 1870000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.no"
# publicsuffix: cannot derive eTLD+1 for domain "gov.lb"
# publicsuffix: cannot derive eTLD+1 for domain "wegrow.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gov.lt"
# publicsuffix: cannot derive eTLD+1 for domain "mus.br"
# 1880000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.uk"
# publicsuffix: cannot derive eTLD+1 for domain "is-a-geek.org"
# publicsuffix: cannot derive eTLD+1 for domain "swinoujscie.pl"
# 1890000/4352338
# 1900000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "onthewifi.com"
# publicsuffix: cannot derive eTLD+1 for domain "cn.com"
# publicsuffix: cannot derive eTLD+1 for domain "webhosting.be"
# 1910000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "iwi.nz"
# publicsuffix: cannot derive eTLD+1 for domain "gov.tj"
# publicsuffix: cannot derive eTLD+1 for domain "hi.cn"
# publicsuffix: cannot derive eTLD+1 for domain "mk.ua"
# 1920000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "sch.ae"
# publicsuffix: cannot derive eTLD+1 for domain "ta.it"
# 1930000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "info.sd"
# publicsuffix: cannot derive eTLD+1 for domain "eti.br"
# 1940000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogdns.com"
# publicsuffix: cannot derive eTLD+1 for domain "gov.lr"
# publicsuffix: cannot derive eTLD+1 for domain "dnsalias.com"
# publicsuffix: cannot derive eTLD+1 for domain "gov.ba"
# publicsuffix: cannot derive eTLD+1 for domain "lezajsk.pl"
# 1950000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.hr"
# publicsuffix: cannot derive eTLD+1 for domain "ks.ua"
# publicsuffix: cannot derive eTLD+1 for domain "mil.ng"
# publicsuffix: cannot derive eTLD+1 for domain "parma.it"
# publicsuffix: cannot derive eTLD+1 for domain "ancona.it"
# publicsuffix: cannot derive eTLD+1 for domain "ok.us"
# 1960000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "rovigo.it"
# 1970000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "pl.ua"
# publicsuffix: cannot derive eTLD+1 for domain "twmail.cc"
# publicsuffix: cannot derive eTLD+1 for domain "edu.gr"
# publicsuffix: cannot derive eTLD+1 for domain "ky.us"
# publicsuffix: cannot derive eTLD+1 for domain "treviso.it"
# 1980000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "university.museum"
# publicsuffix: cannot derive eTLD+1 for domain "edu.ve"
# 1990000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "nic.in"
# publicsuffix: cannot derive eTLD+1 for domain "edu.mg"
# publicsuffix: cannot derive eTLD+1 for domain "ar.com"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.lt"
# publicsuffix: cannot derive eTLD+1 for domain "fastvps-server.com"
# 2000000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "homelinux.net"
# publicsuffix: cannot derive eTLD+1 for domain "bounceme.net"
# publicsuffix: cannot derive eTLD+1 for domain "crimea.ua"
# publicsuffix: cannot derive eTLD+1 for domain "kongsberg.no"
# publicsuffix: cannot derive eTLD+1 for domain "mil.co"
# 2010000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "is.it"
# publicsuffix: cannot derive eTLD+1 for domain "arts.ro"
# publicsuffix: cannot derive eTLD+1 for domain "freeddns.org"
# publicsuffix: cannot derive eTLD+1 for domain "cn.it"
# 2020000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "elasticbeanstalk.com"
# publicsuffix: cannot derive eTLD+1 for domain "mat.br"
# 2030000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.cu"
# publicsuffix: cannot derive eTLD+1 for domain "rybnik.pl"
# publicsuffix: cannot derive eTLD+1 for domain "sa.cr"
# publicsuffix: cannot derive eTLD+1 for domain "ed.cr"
# 2040000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "cs.it"
# publicsuffix: cannot derive eTLD+1 for domain "ltd.uk"
# publicsuffix: cannot derive eTLD+1 for domain "ba.it"
# 2050000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "outsystemscloud.com"
# publicsuffix: cannot derive eTLD+1 for domain "web.pk"
# publicsuffix: cannot derive eTLD+1 for domain "messina.it"
# publicsuffix: cannot derive eTLD+1 for domain "edu.sv"
# publicsuffix: cannot derive eTLD+1 for domain "umbria.it"
# 2060000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "milano.it"
# publicsuffix: cannot derive eTLD+1 for domain "wy.us"
# publicsuffix: cannot derive eTLD+1 for domain "konin.pl"
# publicsuffix: cannot derive eTLD+1 for domain "police.uk"
# 2070000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gok.pk"
# publicsuffix: cannot derive eTLD+1 for domain "hokkaido.jp"
# publicsuffix: cannot derive eTLD+1 for domain "mragowo.pl"
# 2080000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.gy"
# publicsuffix: cannot derive eTLD+1 for domain "servebeer.com"
# publicsuffix: cannot derive eTLD+1 for domain "doesntexist.com"
# 2090000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "plo.ps"
# publicsuffix: cannot derive eTLD+1 for domain "gop.pk"
# publicsuffix: cannot derive eTLD+1 for domain "go.id"
# 2100000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "dedyn.io"
# publicsuffix: cannot derive eTLD+1 for domain "emiliaromagna.it"
# 2110000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "dyndns.org"
# 2120000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.lv"
# publicsuffix: cannot derive eTLD+1 for domain "leg.br"
# 2130000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "kepno.pl"
# publicsuffix: cannot derive eTLD+1 for domain "edu.hk"
# 2140000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "lib.ee"
# publicsuffix: cannot derive eTLD+1 for domain "jus.br"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.se"
# publicsuffix: cannot derive eTLD+1 for domain "laquila.it"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.mk"
# publicsuffix: cannot derive eTLD+1 for domain "edu.mn"
# 2150000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.bz"
# publicsuffix: cannot derive eTLD+1 for domain "gov.kw"
# 2160000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "sosnowiec.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gov.mz"
# publicsuffix: cannot derive eTLD+1 for domain "pe.it"
# 2170000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "edu.sd"
# publicsuffix: cannot derive eTLD+1 for domain "sumy.ua"
# publicsuffix: cannot derive eTLD+1 for domain "sos.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gob.es"
# publicsuffix: cannot derive eTLD+1 for domain "okayama.jp"
# publicsuffix: cannot derive eTLD+1 for domain "mt.it"
# publicsuffix: cannot derive eTLD+1 for domain "gov.lc"
# publicsuffix: cannot derive eTLD+1 for domain "mil.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gv.at"
# 2180000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "id.ir"
# publicsuffix: cannot derive eTLD+1 for domain "wi.us"
# 2190000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "myddns.rocks"
# 2200000/4352338
# 2210000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "vi.it"
# publicsuffix: cannot derive eTLD+1 for domain "msk.ru"
# publicsuffix: cannot derive eTLD+1 for domain "mil.do"
# 2220000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gb.com"
# publicsuffix: cannot derive eTLD+1 for domain "li.it"
# publicsuffix: cannot derive eTLD+1 for domain "uzhgorod.ua"
# publicsuffix: cannot derive eTLD+1 for domain "chieti.it"
# 2230000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "iz.hr"
# publicsuffix: cannot derive eTLD+1 for domain "katowice.pl"
# publicsuffix: cannot derive eTLD+1 for domain "chiba.jp"
# 2240000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "ngrok.io"
# 2250000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "mil.za"
# 2260000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "mine.nu"
# publicsuffix: cannot derive eTLD+1 for domain "swiebodzin.pl"
# publicsuffix: cannot derive eTLD+1 for domain "ostrowiec.pl"
# 2270000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "dynalias.com"
# publicsuffix: cannot derive eTLD+1 for domain "gov.gh"
# publicsuffix: cannot derive eTLD+1 for domain "slupsk.pl"
# publicsuffix: cannot derive eTLD+1 for domain "idv.tw"
# 2280000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.cl"
# 2290000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.mv"
# publicsuffix: cannot derive eTLD+1 for domain "zachpomor.pl"
# 2300000/4352338
# 2310000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "sells-for-u.com"
# publicsuffix: cannot derive eTLD+1 for domain "nt.ca"
# publicsuffix: cannot derive eTLD+1 for domain "psc.br"
# 2320000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "biz.tr"
# publicsuffix: cannot derive eTLD+1 for domain "pa.us"
# publicsuffix: cannot derive eTLD+1 for domain "www.ro"
# publicsuffix: cannot derive eTLD+1 for domain "spb.su"
# 2330000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "macerata.it"
# publicsuffix: cannot derive eTLD+1 for domain "gov.br"
# publicsuffix: cannot derive eTLD+1 for domain "gov.sa"
# 2340000/4352338
# 2350000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "torino.it"
# 2360000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "from.hr"
# publicsuffix: cannot derive eTLD+1 for domain "pyatigorsk.ru"
# publicsuffix: cannot derive eTLD+1 for domain "mielno.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gov.kh"
# publicsuffix: cannot derive eTLD+1 for domain "myds.me"
# publicsuffix: cannot derive eTLD+1 for domain "hl.cn"
# publicsuffix: cannot derive eTLD+1 for domain "lecco.it"
# 2370000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gob.ar"
# publicsuffix: cannot derive eTLD+1 for domain "genova.it"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.ro"
# publicsuffix: cannot derive eTLD+1 for domain "ostrowwlkp.pl"
# 2380000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gob.pa"
# publicsuffix: cannot derive eTLD+1 for domain "sanok.pl"
# 2390000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "bc.ca"
# publicsuffix: cannot derive eTLD+1 for domain "no-ip.biz"
# publicsuffix: cannot derive eTLD+1 for domain "gov.kz"
# publicsuffix: cannot derive eTLD+1 for domain "gsm.pl"
# 2400000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gob.gt"
# publicsuffix: cannot derive eTLD+1 for domain "gouv.fr"
# publicsuffix: cannot derive eTLD+1 for domain "nb.ca"
# publicsuffix: cannot derive eTLD+1 for domain "an.it"
# 2410000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "go.kr"
# publicsuffix: cannot derive eTLD+1 for domain "legnica.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gov.kg"
# publicsuffix: cannot derive eTLD+1 for domain "ketrzyn.pl"
# publicsuffix: cannot derive eTLD+1 for domain "lt.it"
# publicsuffix: cannot derive eTLD+1 for domain "ostroda.pl"
# 2420000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.do"
# publicsuffix: cannot derive eTLD+1 for domain "wroc.pl"
# 2430000/4352338
# 2440000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "bolzano.it"
# publicsuffix: cannot derive eTLD+1 for domain "pt.it"
# publicsuffix: cannot derive eTLD+1 for domain "is-a-geek.com"
# 2450000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "inf.ua"
# publicsuffix: cannot derive eTLD+1 for domain "pila.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gd.cn"
# publicsuffix: cannot derive eTLD+1 for domain "not.br"
# 2460000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gleeze.com"
# 2470000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "putlockers.ck"
# publicsuffix: cannot derive eTLD+1 for domain "servegame.org"
# 2480000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.bd"
# 2490000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "nj.us"
# publicsuffix: cannot derive eTLD+1 for domain "szczytno.pl"
# publicsuffix: cannot derive eTLD+1 for domain "zarow.pl"
# publicsuffix: cannot derive eTLD+1 for domain "benevento.it"
# 2500000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "nom.pl"
# publicsuffix: cannot derive eTLD+1 for domain "dyndns.info"
# publicsuffix: cannot derive eTLD+1 for domain "edu.do"
# publicsuffix: cannot derive eTLD+1 for domain "boleslawiec.pl"
# publicsuffix: cannot derive eTLD+1 for domain "siena.it"
# publicsuffix: cannot derive eTLD+1 for domain "no-ip.ca"
# 2510000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "brindisi.it"
# publicsuffix: cannot derive eTLD+1 for domain "gov.la"
# 2520000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "myftp.org"
# publicsuffix: cannot derive eTLD+1 for domain "of.by"
# publicsuffix: cannot derive eTLD+1 for domain "edu.ua"
# publicsuffix: cannot derive eTLD+1 for domain "sex.pl"
# 2530000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.sn"
# publicsuffix: cannot derive eTLD+1 for domain "glogow.pl"
# publicsuffix: cannot derive eTLD+1 for domain "re.kr"
# publicsuffix: cannot derive eTLD+1 for domain "communications.museum"
# 2540000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "piacenza.it"
# publicsuffix: cannot derive eTLD+1 for domain "unicloud.pl"
# publicsuffix: cannot derive eTLD+1 for domain "nom.si"
# publicsuffix: cannot derive eTLD+1 for domain "venezia.it"
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.com.ar"
# publicsuffix: cannot derive eTLD+1 for domain "idv.hk"
# 2550000/4352338
# ...
# publicsuffix: cannot derive eTLD+1 for domain "go.tz"
# 4180000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "am.br"
# publicsuffix: cannot derive eTLD+1 for domain "bieszczady.pl"
# publicsuffix: cannot derive eTLD+1 for domain "blogdns.net"
# publicsuffix: cannot derive eTLD+1 for domain "fe.it"
# 4190000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "br.it"
# 4200000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.co.nz"
# publicsuffix: cannot derive eTLD+1 for domain "kharkov.ua"
# 4210000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "zakopane.pl"
# publicsuffix: cannot derive eTLD+1 for domain "blackbaudcdn.net"
# publicsuffix: cannot derive eTLD+1 for domain "biella.it"
# 4220000/4352338
# 4230000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "redirectme.net"
# 4240000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.vn"
# publicsuffix: cannot derive eTLD+1 for domain "latina.it"
# publicsuffix: cannot derive eTLD+1 for domain "gov.il"
# publicsuffix: cannot derive eTLD+1 for domain "writesthisblog.com"
# 4250000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "serveblog.net"
# publicsuffix: cannot derive eTLD+1 for domain "int.ru"
# publicsuffix: cannot derive eTLD+1 for domain "bodo.no"
# publicsuffix: cannot derive eTLD+1 for domain "toscana.it"
# 4260000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "zapto.org"
# publicsuffix: cannot derive eTLD+1 for domain "cz.it"
# publicsuffix: cannot derive eTLD+1 for domain "chirurgiens-dentistes.fr"
# 4270000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "dyndns-server.com"
# publicsuffix: cannot derive eTLD+1 for domain "blogsite.org"
# publicsuffix: cannot derive eTLD+1 for domain "nf.ca"
# 4280000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gouv.ht"
# publicsuffix: cannot derive eTLD+1 for domain "gov.dz"
# publicsuffix: cannot derive eTLD+1 for domain "dr.tr"
# 4290000/4352338
# 4300000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "myjino.ru"
# 4310000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "dreamhosters.com"
# publicsuffix: cannot derive eTLD+1 for domain "emp.br"
# publicsuffix: cannot derive eTLD+1 for domain "from-ne.com"
# publicsuffix: cannot derive eTLD+1 for domain "gustan.ye"
# publicsuffix: cannot derive eTLD+1 for domain "in.us"
# publicsuffix: cannot derive eTLD+1 for domain "saitama.jp"
# 4320000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "gov.bt"
# publicsuffix: cannot derive eTLD+1 for domain "gorlice.pl"
# publicsuffix: cannot derive eTLD+1 for domain "gov.gi"
# publicsuffix: cannot derive eTLD+1 for domain "w.se"
# 4330000/4352338
# 4340000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "blogspot.co.uk"
# publicsuffix: cannot derive eTLD+1 for domain "mi.us"
# 4350000/4352338
# publicsuffix: cannot derive eTLD+1 for domain "servehttp.com"
# publicsuffix: cannot derive eTLD+1 for domain "ddnslive.com"
# 1309 bad domains
# {'',
#  'olecko.pl',
#  'virtual.museum',
#  'ostroleka.pl',
#  'gouv.bj',
#  'edu.gr',
#  'cim.br',
#  'hyogo.jp',
#  'fc.it',
#  'tn.it',
#  'srv.br',
#  'standard.',
#  'theworkpc.com',
#  'jaworzno.pl',
#  'cri.nz',
#  'ppg.br',
#  'servepics.com',
#  'ddnsking.com',
#  'no-ip.net',
#  't.se',
#  'ilawa.pl',
#  'za.net',
#  'ddns.net',
#  'gov.uk',
#  'zgora.pl',
#  'legnica.pl',
#  'school.nz',
#  'vlog.br',
#  'asker.no',
#  'googleapis.com',
#  'edu.bz',
#  'edu.gy',
#  'gov.so',
#  'gov.sa',
#  'web.za',
#  'ct.us',
#  'ed.jp',
#  'en.it',
#  'blogsite.org',
#  'edu.bb',
#  'nagasaki.jp',
#  'jus.br',
#  'gov.kg',
#  'pp.ua',
#  'macerata.it',
#  've.it',
#  'gov.mv',
#  'lt.it',
#  'g12.br',
#  'piacenza.it',
#  'gov.mg',
#  'hepforge.org',
#  'edu.kz',
#  'cloudns.cc',
#  'blogspot.com',
#  'fhs.no',
#  'film.hu',
#  'myds.me',
#  'ns.ca',
#  'hl.cn',
#  '.4 e         \x7f',
#  'edu.qa',
#  'gob.cl',
#  'info.ec',
#  'go.ke',
#  'thruhere.net',
#  'spb.su',
#  'dn.ua',
#  'gov.ck',
#  'sch.ng',
#  'serveftp.net',
#  'nom.pl',
#  'wloclawek.pl',
#  'kaszuby.pl',
#  'gov.mw',
#  'pesaro-urbino.it',
#  'blogspot.lt',
#  'cuneo.it',
#  'tur.br',
#  'blogsyte.com',
#  'github.io',
#  'ks.ua',
#  'beep.pl',
#  'nom.uy',
#  'savona.it',
#  'blogspot.co.at',
#  'go.it',
#  'gorlice.pl',
#  'edu.lc',
#  'gov.kw',
#  'sklep.pl',
#  'sicilia.it',
#  'ro.it',
#  'blog.br',
#  'onthewifi.com',
#  'edu.ng',
#  'rovigo.it',
#  'psi.br',
#  'ed.ao',
#  'sandcats.io',
#  'gov.sb',
#  'gov.ae',
#  'web.tr',
#  'jgora.pl',
#  'mi.us',
#  'starachowice.pl',
#  'ca.us',
#  'okinawa.jp',
#  'pc.it',
#  'wolomin.pl',
#  'servequake.com',
#  'como.it',
#  'gov.jm',
#  'gob.pe',
#  'uni5.net',
#  'edu.eg',
#  'gov.il',
#  'blogspot.am',
#  'blogspot.jp',
#  'putlockers.ck',
#  'lecco.it',
#  'nj.us',
#  'rnu.tn',
#  'gov.gn',
#  'blogdns.com',
#  'fi.it',
#  'is-a-geek.net',
#  'poniatowa.pl',
#  'grosseto.it',
#  'jpn.com',
#  'servebbs.com',
#  'youtube.ck',
#  'vet.br',
#  'damnserver.com',
#  'webredirect.org',
#  'varese.it',
#  'bplaced.net',
#  'mat.br',
#  'dr.tr',
#  'gov.ma',
#  'ostroda.pl',
#  'gov.bb',
#  'edu.zm',
#  'soundcast.me',
#  'pl.ua',
#  'dvrdns.org',
#  'gdansk.pl',
#  'knightpoint.systems',
#  'point2this.com',
#  'kolobrzeg.pl',
#  'blogspot.cz',
#  'art.br',
#  'boleslawiec.pl',
#  'cc.ua',
#  'redirectme.net',
#  'swidnica.pl',
#  'gov.ir',
#  'def.br',
#  'gov.mr',
#  'edu.co',
#  'edu.br',
#  'mil.kr',
#  'info.ve',
#  'rybnik.pl',
#  'nc.tr',
#  'toscana.it',
#  'powiat.pl',
#  'mo.it',
#  'uzhgorod.ua',
#  'vgs.no',
#  'czeladz.pl',
#  'ky.us',
#  'kyoto.jp',
#  'gov.ph',
#  'laquila.it',
#  'zachpomor.pl',
#  'ok.us',
#  'ddnss.de',
#  'info.sd',
#  'net-freaks.com',
#  'chieti.it',
#  'gov.ar',
#  'tokyo.jp',
#  'url.tw',
#  'gov.ua',
#  'doesntexist.com',
#  'in.us',
#  'jp.net',
#  'bio.br',
#  'nsw.au',
#  'nom.si',
#  'nom.al',
#  'br.it',
#  'gov.scot',
#  'saitama.jp',
#  'agro.pl',
#  'edu.al',
#  'blackbaudcdn.net',
#  'discovery.',
#  'mie.jp',
#  'olsztyn.pl',
#  'is-by.us',
#  'blogspot.com.br',
#  'ln.cn',
#  'ufcfan.org',
#  'podlasie.pl',
#  'govt.nz',
#  'rn.it',
#  'mail.pl',
#  'gov.ie',
#  'gov.la',
#  'mil.gh',
#  'bt.it',
#  'shizuoka.jp',
#  'mn.it',
#  'idf.il',
#  'blogspot.com.cy',
#  'twmail.net',
#  'asso.fr',
#  'inf.cu',
#  'kh.ua',
#  '64-b.it',
#  'dnsiskinky.com',
#  'gov.iq',
#  'homelinux.net',
#  'dyndns-server.com',
#  'bergamo.it',
#  'shop.pl',
#  'bel.tr',
#  'my-vigor.de',
#  'edu.gi',
#  'edu.sa',
#  'int.ru',
#  'lublin.pl',
#  'notaires.fr',
#  'sa.it',
#  'edu.om',
#  'dynalias.com',
#  'gov.ru',
#  'synology.me',
#  'edu.kh',
#  'greta.fr',
#  'abruzzo.it',
#  'bielawa.pl',
#  'kharkiv.ua',
#  'chambagri.fr',
#  'katowice.pl',
#  'iwi.nz',
#  'rzeszow.pl',
#  'cc.or.us',
#  'zj.cn',
#  'ringsaker.no',
#  'myddns.rocks',
#  'sc.kr',
#  'hk.cn',
#  'gov.me',
#  'tur.ar',
#  'nov.su',
#  'cieszyn.pl',
#  'napoli.it',
#  'edu.mk',
#  'treviso.it',
#  'ae.org',
#  'gov.om',
#  'edu.bn',
#  'ms.us',
#  'fukushima.jp',
#  'zhitomir.ua',
#  'bc.ca',
#  'blogspot.com.es',
#  'go.tz',
#  'gov.gi',
#  'msk.ru',
#  'debian.net',
#  'mil.id',
#  'bbs.tr',
#  'servebeer.com',
#  'gok.pk',
#  'gouv.fr',
#  'gov.af',
#  'sondrio.it',
#  'on.ca',
#  'asn.au',
#  'volyn.ua',
#  'go.id',
#  'mil.ru',
#  'es.kr',
#  'kongsberg.no',
#  'szczytno.pl',
#  'gov.kz',
#  'adv.br',
#  'from-ga.com',
#  'me.us',
#  'tsk.tr',
#  'se.net',
#  'ed.cr',
#  'ma.us',
#  'yk.ca',
#  'agrigento.it',
#  'gob.pa',
#  'kepno.pl',
#  'name.tr',
#  'kutno.pl',
#  'webhop.org',
#  'edu.mg',
#  'edu.mx',
#  'carrd.co',
#  'wmflabs.org',
#  'homeunix.net',
#  'dnsalias.org',
#  'withgoogle.com',
#  'edu.bd',
#  'caserta.it',
#  'bialystok.pl',
#  'med.pro',
#  'gov.lr',
#  'ogliastra.it',
#  'edu.af',
#  'ag.it',
#  'edu.sg',
#  'krakow.pl',
#  'is-a-geek.org',
#  'blogspot.co.uk',
#  'blogspot.pt',
#  'kalisz.pl',
#  'hasura-app.io',
#  'de.com',
#  'gov.sy',
#  'remotewd.com',
#  'gov.cm',
#  'bedzin.pl',
#  'fvg.it',
#  'pp.ru',
#  'biz.mm',
#  'sinaapp.com',
#  'sch.id',
#  'kinghost.net',
#  'gov.ki',
#  'now-dns.top',
#  'edu.gh',
#  'ba.it',
#  'ath.cx',
#  'spb.ru',
#  'jx.cn',
#  'dreamhosters.com',
#  'edu.me',
#  'us.org',
#  'dyndns-at-work.com',
#  'info.na',
#  'leg.br',
#  'parliament.nz',
#  'sa.cr',
#  'eu.int',
#  'al.us',
#  'priv.at',
#  'lg.jp',
#  'dyn-vpn.de',
#  'edu.so',
#  'pruszkow.pl',
#  'endofinternet.org',
#  'fg.it',
#  'poznan.pl',
#  'sardegna.it',
#  'firewall-gateway.de',
#  'bologna.it',
#  'elblag.pl',
#  'edu.ec',
#  'gob.pk',
#  'dyndns-office.com',
#  'gliwice.pl',
#  'lebork.pl',
#  'google.ck',
#  'pro.br',
#  'no-ip.ca',
#  'psc.br',
#  'rawa-maz.pl',
#  'arts.ro',
#  'gotdns.com',
#  'no-ip.info',
#  'edu.dz',
#  'nsn.us',
#  'imperia.it',
#  'venezia.it',
#  'spdns.org',
#  'gov.bs',
#  'tp.it',
#  'blogspot.mk',
#  'edu.ar',
#  'gov.py',
#  'ostrowwlkp.pl',
#  'gov.br',
#  'kasserver.com',
#  'to.it',
#  'gov.cn',
#  'av.it',
#  'pulawy.pl',
#  'london.museum',
#  'not.br',
#  'lecce.it',
#  'edu.mn',
#  'cable-modem.org',
#  'edu.ly',
#  'vb.it',
#  'nysa.pl',
#  'vda.it',
#  'firenze.it',
#  'ascolipiceno.it',
#  'edu.rs',
#  'gov.mn',
#  'health.vn',
#  're.kr',
#  'lubartow.pl',
#  'roma.it',
#  'sch.ir',
#  'waw.pl',
#  'fin.ec',
#  'sytes.net',
#  'dyndns.tv',
#  'goip.de',
#  'pointto.us',
#  'dyndns-ip.com',
#  'gr.jp',
#  'uz.ua',
#  'in-berlin.de',
#  'unicloud.pl',
#  'elk.pl',
#  'mil.co',
#  'gov.do',
#  'lviv.ua',
#  'pg.it',
#  'port.fr',
#  'on-aptible.com',
#  'aq.it',
#  'id.us',
#  'gov.bn',
#  'nhs.uk',
#  'gov.tn',
#  'tm.fr',
#  'leadpages.co',
#  'gmina.pl',
#  'lezajsk.pl',
#  'laspezia.it',
#  'mypsx.net',
#  '3utilities.com',
#  'gov.mz',
#  'me.it',
#  'gov.sg',
#  'ens.tn',
#  'fot.br',
#  'hitra.no',
#  'cleverapps.io',
#  'ap.it',
#  'blogspot.ru',
#  'gov.ly',
#  'sanok.pl',
#  'qld.au',
#  'livorno.it',
#  'blogspot.com.eg',
#  'mt.us',
#  'blogspot.co.id',
#  'edu.hk',
#  'wroc.pl',
#  'jelenia-gora.pl',
#  'info.ro',
#  'latina.it',
#  'sells-for-u.com',
#  'odessa.ua',
#  'ven.it',
#  'iwate.jp',
#  'swinoujscie.pl',
#  'eu.org',
#  'coal.museum',
#  'blogspot.li',
#  'travel.pl',
#  'vic.au',
#  'mil.np',
#  'is-slick.com',
#  'ut.us',
#  'gov.ge',
#  'pt.it',
#  'bari.it',
#  'inf.br',
#  'biz.pl',
#  'gov.ng',
#  'no.com',
#  'firm.in',
#  'blogspot.sk',
#  'emiliaromagna.it',
#  'info.hu',
#  'art.museum',
#  'ra.it',
#  'temp-dns.com',
#  'catania.it',
#  'blogspot.com.uy',
#  'gov.my',
#  'myjino.ru',
#  'gov.al',
#  'tarnobrzeg.pl',
#  'konin.pl',
#  'now.sh',
#  'dnsalias.net',
#  'tychy.pl',
#  'km.ua',
#  'tx.us',
#  'zgorzelec.pl',
#  'edu.az',
#  'oristano.it',
#  'blogspot.nl',
#  'servegame.org',
#  'iz.hr',
#  'mil.ve',
#  'ks.us',
#  'chiba.jp',
#  'edu.ua',
#  'nf.ca',
#  'edu.pe',
#  'edu.ht',
#  'med.pl',
#  'mil.ng',
#  'oita.jp',
#  'palermo.it',
#  'clan.rip',
#  'geek.nz',
#  'cb.it',
#  'dnsalias.com',
#  'fastvps-server.com',
#  'edu.za',
#  'ca.it',
#  'eti.br',
#  'kiev.ua',
#  'gov.gr',
#  'ind.br',
#  'africa.com',
#  'ostrowiec.pl',
#  'radom.pl',
#  'meteorapp.com',
#  'sld.pa',
#  'ru.com',
#  'blogspot.kr',
#  'siracusa.it',
#  'int.mw',
#  'gov.ac',
#  'gov.bh',
#  'gov.lt',
#  'gob.do',
#  'gov.lk',
#  'kommune.no',
#  'gov.qa',
#  'drammen.no',
#  'kanagawa.jp',
#  'radio.fm',
#  'wroclaw.pl',
#  'history.museum',
#  'prato.it',
#  'rnrt.tn',
#  'nv.us',
#  'biz.pk',
#  'edu.bi',
#  'avocat.fr',
#  'res.in',
#  'emilia-romagna.it',
#  'kumamoto.jp',
#  'gov.ve',
#  'kharkov.ua',
#  'szkola.pl',
#  'cremona.it',
#  'hi.cn',
#  'gov.in',
#  'cn.com',
#  'cloudfunctions.net',
#  'bz.it',
#  'sopot.pl',
#  'myphotos.cc',
#  'edu.my',
#  'mielec.pl',
#  'rel.pl',
#  'chirurgiens-dentistes.fr',
#  'gov.ec',
#  'info.pl',
#  'uk.net',
#  'radio.am',
#  'gov.sh',
#  'szczecin.pl',
#  'web.id',
#  'pu.it',
#  'gov.kn',
#  'gen.nz',
#  'edu.cn',
#  'hokkaido.jp',
#  'homedns.org',
#  'pp.se',
#  'duckdns.org',
#  'lo.it',
#  'skoczow.pl',
#  'on-web.fr',
#  'piemonte.it',
#  'yolasite.com',
#  'rm.it',
#  'homeip.net',
#  'edu.la',
#  'ri.us',
#  'lucca.it',
#  'ar.it',
#  'nat.tn',
#  'science.museum',
#  'pe.ca',
#  'dy.fi',
#  'withyoutube.com',
#  'parma.it',
#  'plo.ps',
#  'maori.nz',
#  'myvnc.com',
#  'mazowsze.pl',
#  'tozsde.hu',
#  'okayama.jp',
#  'k12.il',
#  'gov.np',
#  'communications.museum',
#  'lib.ee',
#  'sv.it',
#  'web.lk',
#  'eu.com',
#  'me.ke',
#  'blogspot.com.ar',
#  'mb.it',
#  'fastblog.net',
#  'gen.tr',
#  'gov.ms',
#  'press.ma',
#  'ia.us',
#  'karpacz.pl',
#  'lc.it',
#  'edu.ru',
#  'gov.tt',
#  'odo.br',
#  'game-host.org',
#  'bn.it',
#  'crimea.ua',
#  'edu.vn',
#  'avellino.it',
#  'so.it',
#  'go.ug',
#  'pa.it',
#  'ustka.pl',
#  'mi.th',
#  'hs.kr',
#  'edu.mt',
#  'az.us',
#  'art.pl',
#  'md.us',
#  'aol.ck',
#  'edu.cu',
#  'emp.br',
#  'ri.it',
#  'glitch.me',
#  'blogspot.it',
#  'muni.il',
#  'blogspot.ae',
#  'pz.it',
#  'lukow.pl',
#  'sci.eg',
#  'nov.ru',
#  'grajewo.pl',
#  'gov.dz',
#  'blogspot.ch',
#  'pesarourbino.it',
#  'edu.ve',
#  'fe.it',
#  'targi.pl',
#  'mil.uy',
#  'gov.bf',
#  'go.cr',
#  'serveftp.com',
#  'wi.us',
#  'synology-ds.de',
#  'is-leet.com',
#  'bplaced.com',
#  'nc.us',
#  'aichi.jp',
#  'tv.it',
#  'ud.it',
#  'dyndns.org',
#  'verona.it',
#  'gov.ps',
#  'gb.com',
#  'sch.ae',
#  'at.it',
#  'blogspot.be',
#  'gniezno.pl',
#  'wodzislaw.pl',
#  'cloudaccess.net',
#  'pila.pl',
#  'police.uk',
#  'ge.it',
#  'br.com',
#  'pc.pl',
#  'mil.by',
#  'mil.al',
#  'webhosting.be',
#  'from-ok.com',
#  'ny.us',
#  'freeddns.org',
#  'olawa.pl',
#  'suwalki.pl',
#  'nl.ca',
#  'coop.br',
#  'po.it',
#  'molise.it',
#  'k12.co.us',
#  'dp.ua',
#  'lazio.it',
#  'milano.it',
#  'wy.us',
#  'pri.ee',
#  'nagano.jp',
#  'js.org',
#  'vinnica.ua',
#  'servemp3.com',
#  'from-ne.com',
#  'blogspot.fr',
#  'sn.cn',
#  'ch.it',
#  'edu.au',
#  'messina.it',
#  'dyndns.info',
#  'blogspot.co.nz',
#  'blogspot.qa',
#  'sd.us',
#  'ind.in',
#  'gov.co',
#  'blogspot.ug',
#  'gouv.sn',
#  'readthedocs.io',
#  'ternopil.ua',
#  'kagawa.jp',
#  'lapy.pl',
#  'servep2p.com',
#  'gov.pg',
#  'imb.br',
#  'eco.br',
#  'edu.et',
#  'pomorskie.pl',
#  'tochigi.jp',
#  'blogspot.hr',
#  'mil.ar',
#  'nom.es',
#  'basilicata.it',
#  'slask.pl',
#  'gov.it',
#  'vr.it',
#  'limanowa.pl',
#  'sk.ca',
#  'zarow.pl',
#  'miasta.pl',
#  'belluno.it',
#  'cagliari.it',
#  'draydns.de',
#  'definima.net',
#  'jdevcloud.com',
#  'blogspot.de',
#  'tw.cn',
#  'edu.sv',
#  'webhop.me',
#  'edu.mo',
#  'folkebibl.no',
#  'wv.us',
#  'med.sa',
#  'no-ip.biz',
#  'gov.gh',
#  'servecounterstrike.com',
#  'blogspot.ro',
#  'ngrok.io',
#  're.it',
#  'asso.nc',
#  'if.ua',
#  'med.ec',
#  'bolt.hu',
#  'vi.it',
#  'k12.ec',
#  'mayfirst.org',
#  'nb.ca',
#  'od.ua',
#  'biz.tr',
#  'blogspot.bg',
#  'gov.hk',
#  'gob.ar',
#  'servehttp.com',
#  'pa.us',
#  'mt.it',
#  'nm.us',
#  'siena.it',
#  'mil.ec',
#  'edu.ni',
#  'is-a-geek.com',
#  'we.bs',
#  '32-b.it',
#  'malbork.pl',
#  'gov.ee',
#  'edu.sd',
#  'spdns.de',
#  'nfshost.com',
#  'gouv.ht',
#  'salerno.it',
#  'campania.it',
#  'teramo.it',
#  'cr.it',
#  'gov.sl',
#  'selfip.com',
#  'from-ca.com',
#  'blogspot.in',
#  'mil.br',
#  'turek.pl',
#  'ddnss.org',
#  'gob.ni',
#  'noip.us',
#  'eating-organic.net',
#  'gov.lc',
#  'blogspot.sg',
#  'pol.tr',
#  'gov.zw',
#  'blogspot.ie',
#  'gov.et',
#  'mil.ae',
#  'pro.vn',
#  'wakayama.jp',
#  'cscheater.er',
#  'w.se',
#  'info.tr',
#  'edu.uy',
#  'ru.net',
#  'uk.com',
#  'cn.it',
#  'tv.tr',
#  'przeworsk.pl',
#  'game.tw',
#  'rimini.it',
#  'database.museum',
#  'gov.bm',
#  'mn.us',
#  'puglia.it',
#  'tm.pl',
#  'edu.in',
#  'pescara.it',
#  'ce.it',
#  'edu.bh',
#  'gov.cl',
#  'pd.it',
#  'sc.us',
#  'gov.to',
#  'gov.eg',
#  'emr.it',
#  'edu.krd',
#  'fr.it',
#  'gov.au',
#  'kartuzy.pl',
#  'yn.cn',
#  'edu.lk',
#  'ketrzyn.pl',
#  'mb.ca',
#  'blogspot.com.au',
#  'edu.tr',
#  'jor.br',
#  'ms.kr',
#  'aviation.museum',
#  'blogspot.cl',
#  'blogspot.se',
#  'turystyka.pl',
#  'edu.pl',
#  'al.it',
#  'square7.ch',
#  'synology-diskstation.de',
#  'gov.tr',
#  'pv.it',
#  'school.za',
#  'sumy.ua',
#  'gov.tw',
#  'pvt.ge',
#  'us.com',
#  'bloxcms.com',
#  'mp.br',
#  'bj.cn',
#  'name.vn',
#  'pomorze.pl',
#  'gov.vn',
#  'edu.ee',
#  'gov.zm',
#  'gov.tl',
#  'dnshome.de',
#  'swiebodzin.pl',
#  'gouv.ml',
#  'cn.ua',
#  'gov.cy',
#  'arezzo.it',
#  'dynvpn.de',
#  'sc.ug',
#  'av.tr',
#  'edu.es',
#  'blogspot.no',
#  'umbria.it',
#  'gop.pk',
#  'malopolska.pl',
#  'bo.it',
#  'olkusz.pl',
#  'k12.or.us',
#  'mielno.pl',
#  'mi.it',
#  'gov.pr',
#  'donetsk.ua',
#  'edu.np',
#  'ck.ua',
#  'leczna.pl',
#  'blogspot.com.ee',
#  'va.us',
#  'club.tw',
#  'gov.sd',
#  'gob.ve',
#  'rv.ua',
#  'tgory.pl',
#  'gov.bt',
#  'gouv.ci',
#  'blogspot.mx',
#  'blogspot.gr',
#  'te.ua',
#  'nu.ca',
#  'mc.it',
#  'udine.it',
#  'gov.dm',
#  'edu.mv',
#  'sr.it',
#  'gob.hn',
#  'sc.ke',
#  'inf.ua',
#  'poltava.ua',
#  'sejny.pl',
#  'la.us',
#  'lib.co.us',
#  'cistron.nl',
#  'edu.ps',
#  'de.us',
#  'sp.it',
#  'cnt.br',
#  'rhcloud.com',
#  'friuliveneziagiulia.it',
#  'gov.ws',
#  'nh.us',
#  'blogspot.hu',
#  'lpusercontent.com',
#  'blogspot.tw',
#  'writesthisblog.com',
#  'gov.pt',
#  'mil.pl',
#  'stargard.pl',
#  'gb.net',
#  'priv.no',
#  'edu.bs',
#  'lpages.co',
#  'lg.ua',
#  'sosnowiec.pl',
#  'gov.az',
#  'edu.hn',
#  'gov.za',
#  'adm.br',
#  'gov.by',
#  'gsm.pl',
#  'mil.nz',
#  'sh.cn',
#  'edu.kg',
#  'gitlab.io',
#  'lima-city.de',
#  'fi.cr',
#  'webhop.net',
#  'gov.ls',
#  'lt.ua',
#  'gov.lv',
#  'square7.de',
#  'bieszczady.pl',
#  'rec.br',
#  'tv.br',
#  'edu.jm',
#  'nieruchomosci.pl',
#  'no.it',
#  'nd.us',
#  'no-ip.co.uk',
#  'wa.us',
#  'myhome-server.de',
#  'sex.pl',
#  'podhale.pl',
#  'esp.br',
#  'ad.jp',
#  'slupsk.pl',
#  'my-router.de',
#  'homelinux.org',
#  'cloudns.asia',
#  'cci.fr',
#  'blogdns.org',
#  'myfirewall.org',
#  'og.ao',
#  'lomza.pl',
#  'edu.pk',
#  'gov.bz',
#  ...}

# %%
print('%s bad domains' % len(bad_domains))
bad_domains
# Out:
# 1309 bad domains
# {'',
#  'olecko.pl',
#  'virtual.museum',
#  'ostroleka.pl',
#  'gouv.bj',
#  'edu.gr',
#  'cim.br',
#  'hyogo.jp',
#  'fc.it',
#  'tn.it',
#  'srv.br',
#  'standard.',
#  'theworkpc.com',
#  'jaworzno.pl',
#  'cri.nz',
#  'ppg.br',
#  'servepics.com',
#  'ddnsking.com',
#  'no-ip.net',
#  't.se',
#  'ilawa.pl',
#  'za.net',
#  'ddns.net',
#  'gov.uk',
#  'zgora.pl',
#  'legnica.pl',
#  'school.nz',
#  'vlog.br',
#  'asker.no',
#  'googleapis.com',
#  'edu.bz',
#  'edu.gy',
#  'gov.so',
#  'gov.sa',
#  'web.za',
#  'ct.us',
#  'ed.jp',
#  'en.it',
#  'blogsite.org',
#  'edu.bb',
#  'nagasaki.jp',
#  'jus.br',
#  'gov.kg',
#  'pp.ua',
#  'macerata.it',
#  've.it',
#  'gov.mv',
#  'lt.it',
#  'g12.br',
#  'piacenza.it',
#  'gov.mg',
#  'hepforge.org',
#  'edu.kz',
#  'cloudns.cc',
#  'blogspot.com',
#  'fhs.no',
#  'film.hu',
#  'myds.me',
#  'ns.ca',
#  'hl.cn',
#  '.4 e         \x7f',
#  'edu.qa',
#  'gob.cl',
#  'info.ec',
#  'go.ke',
#  'thruhere.net',
#  'spb.su',
#  'dn.ua',
#  'gov.ck',
#  'sch.ng',
#  'serveftp.net',
#  'nom.pl',
#  'wloclawek.pl',
#  'kaszuby.pl',
#  'gov.mw',
#  'pesaro-urbino.it',
#  'blogspot.lt',
#  'cuneo.it',
#  'tur.br',
#  'blogsyte.com',
#  'github.io',
#  'ks.ua',
#  'beep.pl',
#  'nom.uy',
#  'savona.it',
#  'blogspot.co.at',
#  'go.it',
#  'gorlice.pl',
#  'edu.lc',
#  'gov.kw',
#  'sklep.pl',
#  'sicilia.it',
#  'ro.it',
#  'blog.br',
#  'onthewifi.com',
#  'edu.ng',
#  'rovigo.it',
#  'psi.br',
#  'ed.ao',
#  'sandcats.io',
#  'gov.sb',
#  'gov.ae',
#  'web.tr',
#  'jgora.pl',
#  'mi.us',
#  'starachowice.pl',
#  'ca.us',
#  'okinawa.jp',
#  'pc.it',
#  'wolomin.pl',
#  'servequake.com',
#  'como.it',
#  'gov.jm',
#  'gob.pe',
#  'uni5.net',
#  'edu.eg',
#  'gov.il',
#  'blogspot.am',
#  'blogspot.jp',
#  'putlockers.ck',
#  'lecco.it',
#  'nj.us',
#  'rnu.tn',
#  'gov.gn',
#  'blogdns.com',
#  'fi.it',
#  'is-a-geek.net',
#  'poniatowa.pl',
#  'grosseto.it',
#  'jpn.com',
#  'servebbs.com',
#  'youtube.ck',
#  'vet.br',
#  'damnserver.com',
#  'webredirect.org',
#  'varese.it',
#  'bplaced.net',
#  'mat.br',
#  'dr.tr',
#  'gov.ma',
#  'ostroda.pl',
#  'gov.bb',
#  'edu.zm',
#  'soundcast.me',
#  'pl.ua',
#  'dvrdns.org',
#  'gdansk.pl',
#  'knightpoint.systems',
#  'point2this.com',
#  'kolobrzeg.pl',
#  'blogspot.cz',
#  'art.br',
#  'boleslawiec.pl',
#  'cc.ua',
#  'redirectme.net',
#  'swidnica.pl',
#  'gov.ir',
#  'def.br',
#  'gov.mr',
#  'edu.co',
#  'edu.br',
#  'mil.kr',
#  'info.ve',
#  'rybnik.pl',
#  'nc.tr',
#  'toscana.it',
#  'powiat.pl',
#  'mo.it',
#  'uzhgorod.ua',
#  'vgs.no',
#  'czeladz.pl',
#  'ky.us',
#  'kyoto.jp',
#  'gov.ph',
#  'laquila.it',
#  'zachpomor.pl',
#  'ok.us',
#  'ddnss.de',
#  'info.sd',
#  'net-freaks.com',
#  'chieti.it',
#  'gov.ar',
#  'tokyo.jp',
#  'url.tw',
#  'gov.ua',
#  'doesntexist.com',
#  'in.us',
#  'jp.net',
#  'bio.br',
#  'nsw.au',
#  'nom.si',
#  'nom.al',
#  'br.it',
#  'gov.scot',
#  'saitama.jp',
#  'agro.pl',
#  'edu.al',
#  'blackbaudcdn.net',
#  'discovery.',
#  'mie.jp',
#  'olsztyn.pl',
#  'is-by.us',
#  'blogspot.com.br',
#  'ln.cn',
#  'ufcfan.org',
#  'podlasie.pl',
#  'govt.nz',
#  'rn.it',
#  'mail.pl',
#  'gov.ie',
#  'gov.la',
#  'mil.gh',
#  'bt.it',
#  'shizuoka.jp',
#  'mn.it',
#  'idf.il',
#  'blogspot.com.cy',
#  'twmail.net',
#  'asso.fr',
#  'inf.cu',
#  'kh.ua',
#  '64-b.it',
#  'dnsiskinky.com',
#  'gov.iq',
#  'homelinux.net',
#  'dyndns-server.com',
#  'bergamo.it',
#  'shop.pl',
#  'bel.tr',
#  'my-vigor.de',
#  'edu.gi',
#  'edu.sa',
#  'int.ru',
#  'lublin.pl',
#  'notaires.fr',
#  'sa.it',
#  'edu.om',
#  'dynalias.com',
#  'gov.ru',
#  'synology.me',
#  'edu.kh',
#  'greta.fr',
#  'abruzzo.it',
#  'bielawa.pl',
#  'kharkiv.ua',
#  'chambagri.fr',
#  'katowice.pl',
#  'iwi.nz',
#  'rzeszow.pl',
#  'cc.or.us',
#  'zj.cn',
#  'ringsaker.no',
#  'myddns.rocks',
#  'sc.kr',
#  'hk.cn',
#  'gov.me',
#  'tur.ar',
#  'nov.su',
#  'cieszyn.pl',
#  'napoli.it',
#  'edu.mk',
#  'treviso.it',
#  'ae.org',
#  'gov.om',
#  'edu.bn',
#  'ms.us',
#  'fukushima.jp',
#  'zhitomir.ua',
#  'bc.ca',
#  'blogspot.com.es',
#  'go.tz',
#  'gov.gi',
#  'msk.ru',
#  'debian.net',
#  'mil.id',
#  'bbs.tr',
#  'servebeer.com',
#  'gok.pk',
#  'gouv.fr',
#  'gov.af',
#  'sondrio.it',
#  'on.ca',
#  'asn.au',
#  'volyn.ua',
#  'go.id',
#  'mil.ru',
#  'es.kr',
#  'kongsberg.no',
#  'szczytno.pl',
#  'gov.kz',
#  'adv.br',
#  'from-ga.com',
#  'me.us',
#  'tsk.tr',
#  'se.net',
#  'ed.cr',
#  'ma.us',
#  'yk.ca',
#  'agrigento.it',
#  'gob.pa',
#  'kepno.pl',
#  'name.tr',
#  'kutno.pl',
#  'webhop.org',
#  'edu.mg',
#  'edu.mx',
#  'carrd.co',
#  'wmflabs.org',
#  'homeunix.net',
#  'dnsalias.org',
#  'withgoogle.com',
#  'edu.bd',
#  'caserta.it',
#  'bialystok.pl',
#  'med.pro',
#  'gov.lr',
#  'ogliastra.it',
#  'edu.af',
#  'ag.it',
#  'edu.sg',
#  'krakow.pl',
#  'is-a-geek.org',
#  'blogspot.co.uk',
#  'blogspot.pt',
#  'kalisz.pl',
#  'hasura-app.io',
#  'de.com',
#  'gov.sy',
#  'remotewd.com',
#  'gov.cm',
#  'bedzin.pl',
#  'fvg.it',
#  'pp.ru',
#  'biz.mm',
#  'sinaapp.com',
#  'sch.id',
#  'kinghost.net',
#  'gov.ki',
#  'now-dns.top',
#  'edu.gh',
#  'ba.it',
#  'ath.cx',
#  'spb.ru',
#  'jx.cn',
#  'dreamhosters.com',
#  'edu.me',
#  'us.org',
#  'dyndns-at-work.com',
#  'info.na',
#  'leg.br',
#  'parliament.nz',
#  'sa.cr',
#  'eu.int',
#  'al.us',
#  'priv.at',
#  'lg.jp',
#  'dyn-vpn.de',
#  'edu.so',
#  'pruszkow.pl',
#  'endofinternet.org',
#  'fg.it',
#  'poznan.pl',
#  'sardegna.it',
#  'firewall-gateway.de',
#  'bologna.it',
#  'elblag.pl',
#  'edu.ec',
#  'gob.pk',
#  'dyndns-office.com',
#  'gliwice.pl',
#  'lebork.pl',
#  'google.ck',
#  'pro.br',
#  'no-ip.ca',
#  'psc.br',
#  'rawa-maz.pl',
#  'arts.ro',
#  'gotdns.com',
#  'no-ip.info',
#  'edu.dz',
#  'nsn.us',
#  'imperia.it',
#  'venezia.it',
#  'spdns.org',
#  'gov.bs',
#  'tp.it',
#  'blogspot.mk',
#  'edu.ar',
#  'gov.py',
#  'ostrowwlkp.pl',
#  'gov.br',
#  'kasserver.com',
#  'to.it',
#  'gov.cn',
#  'av.it',
#  'pulawy.pl',
#  'london.museum',
#  'not.br',
#  'lecce.it',
#  'edu.mn',
#  'cable-modem.org',
#  'edu.ly',
#  'vb.it',
#  'nysa.pl',
#  'vda.it',
#  'firenze.it',
#  'ascolipiceno.it',
#  'edu.rs',
#  'gov.mn',
#  'health.vn',
#  're.kr',
#  'lubartow.pl',
#  'roma.it',
#  'sch.ir',
#  'waw.pl',
#  'fin.ec',
#  'sytes.net',
#  'dyndns.tv',
#  'goip.de',
#  'pointto.us',
#  'dyndns-ip.com',
#  'gr.jp',
#  'uz.ua',
#  'in-berlin.de',
#  'unicloud.pl',
#  'elk.pl',
#  'mil.co',
#  'gov.do',
#  'lviv.ua',
#  'pg.it',
#  'port.fr',
#  'on-aptible.com',
#  'aq.it',
#  'id.us',
#  'gov.bn',
#  'nhs.uk',
#  'gov.tn',
#  'tm.fr',
#  'leadpages.co',
#  'gmina.pl',
#  'lezajsk.pl',
#  'laspezia.it',
#  'mypsx.net',
#  '3utilities.com',
#  'gov.mz',
#  'me.it',
#  'gov.sg',
#  'ens.tn',
#  'fot.br',
#  'hitra.no',
#  'cleverapps.io',
#  'ap.it',
#  'blogspot.ru',
#  'gov.ly',
#  'sanok.pl',
#  'qld.au',
#  'livorno.it',
#  'blogspot.com.eg',
#  'mt.us',
#  'blogspot.co.id',
#  'edu.hk',
#  'wroc.pl',
#  'jelenia-gora.pl',
#  'info.ro',
#  'latina.it',
#  'sells-for-u.com',
#  'odessa.ua',
#  'ven.it',
#  'iwate.jp',
#  'swinoujscie.pl',
#  'eu.org',
#  'coal.museum',
#  'blogspot.li',
#  'travel.pl',
#  'vic.au',
#  'mil.np',
#  'is-slick.com',
#  'ut.us',
#  'gov.ge',
#  'pt.it',
#  'bari.it',
#  'inf.br',
#  'biz.pl',
#  'gov.ng',
#  'no.com',
#  'firm.in',
#  'blogspot.sk',
#  'emiliaromagna.it',
#  'info.hu',
#  'art.museum',
#  'ra.it',
#  'temp-dns.com',
#  'catania.it',
#  'blogspot.com.uy',
#  'gov.my',
#  'myjino.ru',
#  'gov.al',
#  'tarnobrzeg.pl',
#  'konin.pl',
#  'now.sh',
#  'dnsalias.net',
#  'tychy.pl',
#  'km.ua',
#  'tx.us',
#  'zgorzelec.pl',
#  'edu.az',
#  'oristano.it',
#  'blogspot.nl',
#  'servegame.org',
#  'iz.hr',
#  'mil.ve',
#  'ks.us',
#  'chiba.jp',
#  'edu.ua',
#  'nf.ca',
#  'edu.pe',
#  'edu.ht',
#  'med.pl',
#  'mil.ng',
#  'oita.jp',
#  'palermo.it',
#  'clan.rip',
#  'geek.nz',
#  'cb.it',
#  'dnsalias.com',
#  'fastvps-server.com',
#  'edu.za',
#  'ca.it',
#  'eti.br',
#  'kiev.ua',
#  'gov.gr',
#  'ind.br',
#  'africa.com',
#  'ostrowiec.pl',
#  'radom.pl',
#  'meteorapp.com',
#  'sld.pa',
#  'ru.com',
#  'blogspot.kr',
#  'siracusa.it',
#  'int.mw',
#  'gov.ac',
#  'gov.bh',
#  'gov.lt',
#  'gob.do',
#  'gov.lk',
#  'kommune.no',
#  'gov.qa',
#  'drammen.no',
#  'kanagawa.jp',
#  'radio.fm',
#  'wroclaw.pl',
#  'history.museum',
#  'prato.it',
#  'rnrt.tn',
#  'nv.us',
#  'biz.pk',
#  'edu.bi',
#  'avocat.fr',
#  'res.in',
#  'emilia-romagna.it',
#  'kumamoto.jp',
#  'gov.ve',
#  'kharkov.ua',
#  'szkola.pl',
#  'cremona.it',
#  'hi.cn',
#  'gov.in',
#  'cn.com',
#  'cloudfunctions.net',
#  'bz.it',
#  'sopot.pl',
#  'myphotos.cc',
#  'edu.my',
#  'mielec.pl',
#  'rel.pl',
#  'chirurgiens-dentistes.fr',
#  'gov.ec',
#  'info.pl',
#  'uk.net',
#  'radio.am',
#  'gov.sh',
#  'szczecin.pl',
#  'web.id',
#  'pu.it',
#  'gov.kn',
#  'gen.nz',
#  'edu.cn',
#  'hokkaido.jp',
#  'homedns.org',
#  'pp.se',
#  'duckdns.org',
#  'lo.it',
#  'skoczow.pl',
#  'on-web.fr',
#  'piemonte.it',
#  'yolasite.com',
#  'rm.it',
#  'homeip.net',
#  'edu.la',
#  'ri.us',
#  'lucca.it',
#  'ar.it',
#  'nat.tn',
#  'science.museum',
#  'pe.ca',
#  'dy.fi',
#  'withyoutube.com',
#  'parma.it',
#  'plo.ps',
#  'maori.nz',
#  'myvnc.com',
#  'mazowsze.pl',
#  'tozsde.hu',
#  'okayama.jp',
#  'k12.il',
#  'gov.np',
#  'communications.museum',
#  'lib.ee',
#  'sv.it',
#  'web.lk',
#  'eu.com',
#  'me.ke',
#  'blogspot.com.ar',
#  'mb.it',
#  'fastblog.net',
#  'gen.tr',
#  'gov.ms',
#  'press.ma',
#  'ia.us',
#  'karpacz.pl',
#  'lc.it',
#  'edu.ru',
#  'gov.tt',
#  'odo.br',
#  'game-host.org',
#  'bn.it',
#  'crimea.ua',
#  'edu.vn',
#  'avellino.it',
#  'so.it',
#  'go.ug',
#  'pa.it',
#  'ustka.pl',
#  'mi.th',
#  'hs.kr',
#  'edu.mt',
#  'az.us',
#  'art.pl',
#  'md.us',
#  'aol.ck',
#  'edu.cu',
#  'emp.br',
#  'ri.it',
#  'glitch.me',
#  'blogspot.it',
#  'muni.il',
#  'blogspot.ae',
#  'pz.it',
#  'lukow.pl',
#  'sci.eg',
#  'nov.ru',
#  'grajewo.pl',
#  'gov.dz',
#  'blogspot.ch',
#  'pesarourbino.it',
#  'edu.ve',
#  'fe.it',
#  'targi.pl',
#  'mil.uy',
#  'gov.bf',
#  'go.cr',
#  'serveftp.com',
#  'wi.us',
#  'synology-ds.de',
#  'is-leet.com',
#  'bplaced.com',
#  'nc.us',
#  'aichi.jp',
#  'tv.it',
#  'ud.it',
#  'dyndns.org',
#  'verona.it',
#  'gov.ps',
#  'gb.com',
#  'sch.ae',
#  'at.it',
#  'blogspot.be',
#  'gniezno.pl',
#  'wodzislaw.pl',
#  'cloudaccess.net',
#  'pila.pl',
#  'police.uk',
#  'ge.it',
#  'br.com',
#  'pc.pl',
#  'mil.by',
#  'mil.al',
#  'webhosting.be',
#  'from-ok.com',
#  'ny.us',
#  'freeddns.org',
#  'olawa.pl',
#  'suwalki.pl',
#  'nl.ca',
#  'coop.br',
#  'po.it',
#  'molise.it',
#  'k12.co.us',
#  'dp.ua',
#  'lazio.it',
#  'milano.it',
#  'wy.us',
#  'pri.ee',
#  'nagano.jp',
#  'js.org',
#  'vinnica.ua',
#  'servemp3.com',
#  'from-ne.com',
#  'blogspot.fr',
#  'sn.cn',
#  'ch.it',
#  'edu.au',
#  'messina.it',
#  'dyndns.info',
#  'blogspot.co.nz',
#  'blogspot.qa',
#  'sd.us',
#  'ind.in',
#  'gov.co',
#  'blogspot.ug',
#  'gouv.sn',
#  'readthedocs.io',
#  'ternopil.ua',
#  'kagawa.jp',
#  'lapy.pl',
#  'servep2p.com',
#  'gov.pg',
#  'imb.br',
#  'eco.br',
#  'edu.et',
#  'pomorskie.pl',
#  'tochigi.jp',
#  'blogspot.hr',
#  'mil.ar',
#  'nom.es',
#  'basilicata.it',
#  'slask.pl',
#  'gov.it',
#  'vr.it',
#  'limanowa.pl',
#  'sk.ca',
#  'zarow.pl',
#  'miasta.pl',
#  'belluno.it',
#  'cagliari.it',
#  'draydns.de',
#  'definima.net',
#  'jdevcloud.com',
#  'blogspot.de',
#  'tw.cn',
#  'edu.sv',
#  'webhop.me',
#  'edu.mo',
#  'folkebibl.no',
#  'wv.us',
#  'med.sa',
#  'no-ip.biz',
#  'gov.gh',
#  'servecounterstrike.com',
#  'blogspot.ro',
#  'ngrok.io',
#  're.it',
#  'asso.nc',
#  'if.ua',
#  'med.ec',
#  'bolt.hu',
#  'vi.it',
#  'k12.ec',
#  'mayfirst.org',
#  'nb.ca',
#  'od.ua',
#  'biz.tr',
#  'blogspot.bg',
#  'gov.hk',
#  'gob.ar',
#  'servehttp.com',
#  'pa.us',
#  'mt.it',
#  'nm.us',
#  'siena.it',
#  'mil.ec',
#  'edu.ni',
#  'is-a-geek.com',
#  'we.bs',
#  '32-b.it',
#  'malbork.pl',
#  'gov.ee',
#  'edu.sd',
#  'spdns.de',
#  'nfshost.com',
#  'gouv.ht',
#  'salerno.it',
#  'campania.it',
#  'teramo.it',
#  'cr.it',
#  'gov.sl',
#  'selfip.com',
#  'from-ca.com',
#  'blogspot.in',
#  'mil.br',
#  'turek.pl',
#  'ddnss.org',
#  'gob.ni',
#  'noip.us',
#  'eating-organic.net',
#  'gov.lc',
#  'blogspot.sg',
#  'pol.tr',
#  'gov.zw',
#  'blogspot.ie',
#  'gov.et',
#  'mil.ae',
#  'pro.vn',
#  'wakayama.jp',
#  'cscheater.er',
#  'w.se',
#  'info.tr',
#  'edu.uy',
#  'ru.net',
#  'uk.com',
#  'cn.it',
#  'tv.tr',
#  'przeworsk.pl',
#  'game.tw',
#  'rimini.it',
#  'database.museum',
#  'gov.bm',
#  'mn.us',
#  'puglia.it',
#  'tm.pl',
#  'edu.in',
#  'pescara.it',
#  'ce.it',
#  'edu.bh',
#  'gov.cl',
#  'pd.it',
#  'sc.us',
#  'gov.to',
#  'gov.eg',
#  'emr.it',
#  'edu.krd',
#  'fr.it',
#  'gov.au',
#  'kartuzy.pl',
#  'yn.cn',
#  'edu.lk',
#  'ketrzyn.pl',
#  'mb.ca',
#  'blogspot.com.au',
#  'edu.tr',
#  'jor.br',
#  'ms.kr',
#  'aviation.museum',
#  'blogspot.cl',
#  'blogspot.se',
#  'turystyka.pl',
#  'edu.pl',
#  'al.it',
#  'square7.ch',
#  'synology-diskstation.de',
#  'gov.tr',
#  'pv.it',
#  'school.za',
#  'sumy.ua',
#  'gov.tw',
#  'pvt.ge',
#  'us.com',
#  'bloxcms.com',
#  'mp.br',
#  'bj.cn',
#  'name.vn',
#  'pomorze.pl',
#  'gov.vn',
#  'edu.ee',
#  'gov.zm',
#  'gov.tl',
#  'dnshome.de',
#  'swiebodzin.pl',
#  'gouv.ml',
#  'cn.ua',
#  'gov.cy',
#  'arezzo.it',
#  'dynvpn.de',
#  'sc.ug',
#  'av.tr',
#  'edu.es',
#  'blogspot.no',
#  'umbria.it',
#  'gop.pk',
#  'malopolska.pl',
#  'bo.it',
#  'olkusz.pl',
#  'k12.or.us',
#  'mielno.pl',
#  'mi.it',
#  'gov.pr',
#  'donetsk.ua',
#  'edu.np',
#  'ck.ua',
#  'leczna.pl',
#  'blogspot.com.ee',
#  'va.us',
#  'club.tw',
#  'gov.sd',
#  'gob.ve',
#  'rv.ua',
#  'tgory.pl',
#  'gov.bt',
#  'gouv.ci',
#  'blogspot.mx',
#  'blogspot.gr',
#  'te.ua',
#  'nu.ca',
#  'mc.it',
#  'udine.it',
#  'gov.dm',
#  'edu.mv',
#  'sr.it',
#  'gob.hn',
#  'sc.ke',
#  'inf.ua',
#  'poltava.ua',
#  'sejny.pl',
#  'la.us',
#  'lib.co.us',
#  'cistron.nl',
#  'edu.ps',
#  'de.us',
#  'sp.it',
#  'cnt.br',
#  'rhcloud.com',
#  'friuliveneziagiulia.it',
#  'gov.ws',
#  'nh.us',
#  'blogspot.hu',
#  'lpusercontent.com',
#  'blogspot.tw',
#  'writesthisblog.com',
#  'gov.pt',
#  'mil.pl',
#  'stargard.pl',
#  'gb.net',
#  'priv.no',
#  'edu.bs',
#  'lpages.co',
#  'lg.ua',
#  'sosnowiec.pl',
#  'gov.az',
#  'edu.hn',
#  'gov.za',
#  'adm.br',
#  'gov.by',
#  'gsm.pl',
#  'mil.nz',
#  'sh.cn',
#  'edu.kg',
#  'gitlab.io',
#  'lima-city.de',
#  'fi.cr',
#  'webhop.net',
#  'gov.ls',
#  'lt.ua',
#  'gov.lv',
#  'square7.de',
#  'bieszczady.pl',
#  'rec.br',
#  'tv.br',
#  'edu.jm',
#  'nieruchomosci.pl',
#  'no.it',
#  'nd.us',
#  'no-ip.co.uk',
#  'wa.us',
#  'myhome-server.de',
#  'sex.pl',
#  'podhale.pl',
#  'esp.br',
#  'ad.jp',
#  'slupsk.pl',
#  'my-router.de',
#  'homelinux.org',
#  'cloudns.asia',
#  'cci.fr',
#  'blogdns.org',
#  'myfirewall.org',
#  'og.ao',
#  'lomza.pl',
#  'edu.pk',
#  'gov.bz',
#  ...}

# %% [markdown]
# Create a filtered dataframe that just includes machine,week samples where bad domains have been filtered out and where each sample has at least the threshold number of domains (7).

# %%
weeks_machines_domains_f_df = weeks_machines_domains_df.copy()
filter_domains = lambda domains: [d for d in domains if d not in bad_domains]
weeks_machines_domains_f_df['domains'] = weeks_machines_domains_f_df['domains'].apply(filter_domains)
weeks_machines_domains_f_df['n_domains'] = weeks_machines_domains_f_df['domains'].apply(len)

# %%
weeks_machines_domains_f_df.drop('machine_id', axis=1).head()
# Out:
#    week  n_domains                                            domains
# 0     1        119  [homeworkmarket.com, shareably.net, crschools....
# 1     1          0                                                 []
# 2     1          2                        [nbcsports.com, google.com]
# 3     1          5  [signaturesalon.us, tasteofhome.com, facebook....
# 4     1          8  [myway.com, victoryoutreach.org, adobeconnect....

# %%
weeks_machines_domains_f_df['n_domains'].describe()
# Out:
# count    4.877236e+06
# mean     1.318441e+01
# std      1.756159e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      4.000000e+00
# 75%      1.600000e+01
# max      1.502440e+05
# Name: n_domains, dtype: float64

# %%
# make df limited that limits to samples with at least n_domains_threshold
# and maps machine, week --> simhash
weeks_machines_7domains_df = weeks_machines_domains_f_df[(
    weeks_machines_domains_f_df.n_domains >= n_domains_threshold
)].copy()
print('%s/%s samples with at least %s domains' % (
    len(weeks_machines_7domains_df), len(weeks_machines_domains_f_df), n_domains_threshold))
# apply simhash to all rows
time_start = datetime.now()
print(time_start)
weeks_machines_7domains_df['simhash'] = weeks_machines_7domains_df.domains.apply(floc.hashes.sim_hash_string)

time_end = datetime.now()
print(time_end - time_start)
# Out:
# 2073411/4877236 samples with at least 7 domains
# 2021-11-30 15:45:17.366012
# 0:12:41.929379

# %%
weeks_machines_7domains_df.drop('machine_id', axis=1).head()
# Out:
#    week  n_domains                                            domains  \
# 0     1        119  [homeworkmarket.com, shareably.net, crschools....
# 4     1          8  [myway.com, victoryoutreach.org, adobeconnect....
# 6     1         44  [nathanhowemusic.com, ldsmusiconline.com, make...
# 7     1          9  [obsev.com, att.net, auth-gateway.net, msn.com...
# 8     1         35  [actionteaser.ru, translarium.info, kasparov.r...
#
#            simhash
# 0  383898614960440
# 4  836861704428703
# 6  775441426153398
# 7  464574759305230
# 8  352149769230906

# %%
print('how much was dropped by filtering out bad domains and limiting to samples with >= 7 domains?')
print('unfiltered = %s rows' % len(weeks_machines_domains_df))
print('filtered = %s rows' % len(weeks_machines_7domains_df))
dropped_rows = len(weeks_machines_domains_df) - len(weeks_machines_7domains_df)
print('dropped %s = %0.1f%% rows' % (dropped_rows, 100*dropped_rows/len(weeks_machines_domains_df)))

print('\nhow many machines per week after filtering?\n')

weeks_machines_7domains = weeks_machines_7domains_df.groupby(['week'])['machine_id'].nunique()
weeks_machines_7domains_pct = weeks_machines_7domains \
    / weeks_machines_domains_df.groupby(['week'])['machine_id'].nunique()

print(weeks_machines_7domains.describe())
print(weeks_machines_7domains_pct.describe())

fig, ax = plt.subplots(1,1, figsize=(12, 4), dpi=100)
ax.bar(weeks_machines_7domains.index, weeks_machines_7domains)
ax.set_xlim(0, 53)
ax.set_title('number of machines with at least 7 domains per week')
ax.set_ylabel('machines')
ax_pct = ax.twinx()
ax_pct.bar(weeks_machines_7domains_pct.index, weeks_machines_7domains_pct)
_ = ax_pct.set_ylabel('% total machines')
# Out:
# how much was dropped by filtering out bad domains and limiting to samples with >= 7 domains?
# unfiltered = 4877236 rows
# filtered = 2073411 rows
# dropped 2803825 = 57.5% rows
#
# how many machines per week after filtering?
#
# count       52.000000
# mean     39873.288462
# std       2538.641789
# min      34426.000000
# 25%      38096.250000
# 50%      39701.000000
# 75%      42060.500000
# max      43957.000000
# Name: machine_id, dtype: float64
# count    52.000000
# mean      0.425120
# std       0.027066
# min       0.367042
# 25%       0.406174
# 50%       0.423283
# 75%       0.448440
# max       0.468660
# Name: machine_id, dtype: float64

# %% [markdown]
# Create set of all domains used in analysis.
#
# This we can use for random domain set creation for the random comparison.

# %%
good_domains_set = domains_set - bad_domains
print('total good domains:')
len(good_domains_set)
# Out:
# total good domains:
# 4351029

# %% [markdown]
# ### Make FLoC cohorts for sessions data

# %%
import prefixLSH

# %% [markdown]
# We have 500 panels, 52 weeks of data.
#
# We will compute cohorts covering this broad sampling.
#
# To start with... just looking at:
#
# specific panel ID, random week of data
#
#
# We take the panel and add in the simhash computed from the machine_id domains.
#
# Note this step will drop / ignore machine,weeks without enough good domains for the simhash calculation.
#
# TODO: consider whether this is in conflict with the stratified panel sampling.
#
# For the given panel, we then assign cohorts by applying prefixLSH.

# %%
import random

# %%
def get_panel_week_combo(p, debug=True):
    """
    Returns a panel that combines multiple panel ids (p) from different weeks.
    where panel ids and weeks are randomly sampled without replacement
    and each panel id is combined with one week
    """
    panel_ids = np.random.choice(panels_df.panel_id.unique(), size=p, replace=False)
    weeks = np.random.choice(list(range(1,52+1)), size=p, replace=False)
    if debug:
        print('using panel id, week combos:', list(zip(panel_ids, weeks)))
    pdf = panels_df[panels_df.panel_id.isin(panel_ids)].copy()
    pdf['week'] = pdf.panel_id.map(dict(zip(panel_ids, weeks)))
    pdf = pdf.set_index(['machine_id','week'])
    pdf['simhash'] = weeks_machines_7domains_df.set_index(['machine_id','week'])['simhash']
    return pdf

# %%
p = 1
panel_df1 = get_panel_week_combo(p)
panel_df1.head()
# Out:
# using panel id, week combos: [(52, 27)]
#                   household_income  racial_background  stratify  panel_id  \
# machine_id  week
# 229989826.0 27                   1                1.0  1.0, 1.0        52
# 197118878.0 27                   1                1.0  1.0, 1.0        52
# 202873750.0 27                   1                1.0  1.0, 1.0        52
# 191200019.0 27                   1                1.0  1.0, 1.0        52
# 185808563.0 27                   1                1.0  1.0, 1.0        52
#
#                        simhash
# machine_id  week
# 229989826.0 27             NaN
# 197118878.0 27    1.000486e+15
# 202873750.0 27    2.757570e+13
# 191200019.0 27    7.178128e+14
# 185808563.0 27    6.599737e+14

# %% [markdown]
# Question:
#
# Is the panel still representative of the population after we drop samples without sufficient browser history?
#
# If not, how different is it?

# %%
race_values = {1:'white', 2:'black', 3:'asian', 5:'other'}
hi_values = {1:'0 to 25k', 2:'25k to 50k', 3:'50k to 100k', 4:'100k +'}
hi_race_values = {
    "1.0, 1.0": "0 to 25k, white",
    "2.0, 1.0": "25k to 50k, white",
    "3.0, 1.0": "50k to 100k, white",
    "4.0, 1.0": "100k +, white",
    
    "1.0, 2.0": "0 to 25k, black",
    "2.0, 2.0": "25k to 50k, black",
    "3.0, 2.0": "50k to 100k, black",
    "4.0, 2.0": "100k +, black",
    
    "1.0, 3.0": "0 to 25k, asian",
    "2.0, 3.0": "25k to 50k, asian",
    "3.0, 3.0": "50k to 100k, asian",
    "4.0, 3.0": "100k +, asian",
    
    "1.0, 5.0": "0 to 25k, other",
    "2.0, 5.0": "25k to 50k, other",
    "3.0, 5.0": "50k to 100k, other",
    "4.0, 5.0": "100k +, other",
}

# %%
demo_col_values = [
    ('racial_background', race_values),
    ('household_income', hi_values),
    ('stratify', hi_race_values),
]
    
for demo_col, demo_values in demo_col_values:
    values = race_values
    demo_counts_df = (
        panel_df1.groupby(demo_col)['panel_id'].count() / len(panel_df1)
    ).rename('fraction in panel').to_frame()
    demo_counts_df['fraction in cohorts'] = panel_df1.groupby(demo_col)['cohort'].count()/panel_df1.groupby(demo_col)['cohort'].count().sum()
    fig,ax = plt.subplots(1,1,figsize=(4,2),dpi=150)
    demo_counts_df.plot.bar(ax=ax)
    x_label = demo_counts_df.index.map(demo_values)
    ax.set_xticklabels(x_label)
    ax.set_xlabel('')
    plt.show()
demo_counts_df
# Out:
#           fraction in panel  fraction in cohorts
# stratify
# 1.0, 1.0           0.141857             0.125175
# 1.0, 2.0           0.043636             0.034448
# 1.0, 3.0           0.007739             0.009213
# 1.0, 5.0           0.007492             0.004406
# 2.0, 1.0           0.165981             0.170639
# 2.0, 2.0           0.034744             0.025436
# 2.0, 3.0           0.008398             0.009413
# 2.0, 5.0           0.007410             0.004606
# 3.0, 1.0           0.233493             0.241338
# 3.0, 2.0           0.033591             0.026437
# 3.0, 3.0           0.014490             0.015822
# 3.0, 5.0           0.008562             0.008812
# 4.0, 1.0           0.243125             0.274384
# 4.0, 2.0           0.021242             0.018226
# 4.0, 3.0           0.022147             0.025436
# 4.0, 5.0           0.006093             0.006209

# %%
# compute / assign cohorts
# note we will drop / ignore machine,weeks without sufficient domains for simhash

cohorts_dict = prefixLSH.get_cohorts_dict(panel_df1.dropna()['simhash'].astype(int), min_k=40)
panel_df1['cohort'] = panel_df1['simhash'].map(cohorts_dict)

print("%s cohorts" % panel_df1["cohort"].nunique())
assert(panel_df1["cohort"].max() == panel_df1["cohort"].nunique())

print("%s samples (rows)" % len(panel_df1.dropna()))
print("%0.1f avg samples per cohort" % (len(panel_df1.dropna())/panel_df1["cohort"].nunique()))
# Out:
# 78 cohorts
# 4993 samples (rows)
# 64.0 avg samples per cohort

# %%
print('cohort sizes:')
print(panel_df1["cohort"].value_counts())

fig,ax = plt.subplots(1,1,figsize=(3,1), dpi=100)
panel_df1["cohort"].value_counts().hist(ax=ax)
plt.ylabel("cohorts")
_ = plt.xlabel("cohort size")
plt.show()
fig,ax = plt.subplots(1,1,figsize=(3,1), dpi=100)
panel_df1["cohort"].value_counts().hist(ax=ax, bins=50)
plt.ylabel("cohorts")
_ = plt.xlabel("cohort size")
# Out:
# cohort sizes:
# 46.0    119
# 34.0    118
# 9.0     108
# 56.0     99
# 1.0      98
#        ...
# 28.0     42
# 73.0     42
# 71.0     42
# 30.0     41
# 22.0     41
# Name: cohort, Length: 78, dtype: int64

# %% [markdown]
# #### Look at demographic distribution across cohorts

# %%
def get_cohort_demo_portions_df(panel_df, demo_col):
    df = panel_df.groupby(
        ['cohort', demo_col]
    ).count()['panel_id'].rename('count').to_frame().reset_index(demo_col)
    df['total'] = panel_df.groupby('cohort').count()['panel_id']
    df['portion'] = df['count']/df['total']
    return df

# %%
dpi = 100
t = 0.1

def plot_cohort_demo_portions(panel_df, demo_col, demo_value_names_dict):
    cohort_demo_portions_df = get_cohort_demo_portions_df(panel_df, demo_col)
    demo_fractions = panel_df.dropna().groupby(demo_col)['panel_id'].count() / len(panel_df.dropna())
    
    for val in demo_value_names_dict:
        print('%s' % demo_value_names_dict[val])
        cohort_demo_mean = cohort_demo_portions_df[cohort_demo_portions_df[demo_col]==val].portion.mean()
        print('mean fraction %s across cohorts = %0.2f' % (demo_value_names_dict[val], cohort_demo_mean))
        # Google's sensitivity analysis actually looked at avg for sensitive categories
        # across all users rather than across cohorts
        demo_fraction = demo_fractions[val]
        print('fraction %s across all users in cohorts = %0.2f' % (demo_value_names_dict[val], demo_fraction))

        fig,ax = plt.subplots(1,1,figsize=(6,3), dpi=dpi)
        cohort_demo_portions_df[cohort_demo_portions_df[demo_col]==val].portion.sort_values(ascending=False).plot.bar(ax=ax, label="")

        ax.hlines(y=demo_fraction, xmin=0, xmax=len(ax.get_xticks()), 
                  linestyles='-', color='black', label='mean')
        if (demo_fraction - t) > 0:
            ax.hlines(y=demo_fraction-t, xmin=0, xmax=len(ax.get_xticks()), 
                      linestyles='--', color='black', label='mean - t=0.1')
        ax.hlines(y=demo_fraction+t, xmin=0, xmax=len(ax.get_xticks()), 
                  linestyles='--', color='black', label='mean + t=0.1')
        #ax.legend()
        ax.set_xticks([])
        ax.set_xlabel('cohorts')
        ax.set_ylabel('fraction "%s"' % demo_value_names_dict[val])
        plt.show()
    
    return cohort_demo_portions_df

# %% [markdown]
# Looking at race

# %%
race1 = plot_cohort_demo_portions(panel_df1, 'racial_background', race_values)
race1.head()
# Out:
# white
# mean fraction white across cohorts = 0.81
# fraction white across all users in cohorts = 0.81
# black
# mean fraction black across cohorts = 0.10
# fraction black across all users in cohorts = 0.10
# asian
# mean fraction asian across cohorts = 0.06
# fraction asian across all users in cohorts = 0.06
# other
# mean fraction other across cohorts = 0.03
# fraction other across all users in cohorts = 0.02
#         racial_background  count  total   portion
# cohort
# 1.0                   1.0     69     98  0.704082
# 1.0                   2.0     24     98  0.244898
# 1.0                   3.0      4     98  0.040816
# 1.0                   5.0      1     98  0.010204
# 2.0                   1.0     67     86  0.779070

# %%
panels_df[panels_df.panel_id==panel_id]['racial_background'].value_counts()/len(panels_df[panels_df.panel_id==panel_id])
# Out:
# 1.0    0.784456
# 2.0    0.133213
# 3.0    0.052775
# 5.0    0.029557
# Name: racial_background, dtype: float64

# %% [markdown]
# Looking at just household income

# %%
print(panels_df[panels_df.panel_id==panel_id]['household_income'].value_counts()/len(panels_df[panels_df.panel_id==panel_id]))
print('\n')
hi1 = plot_cohort_demo_portions(panel_df1, 'household_income', hi_values)
hi1.head()
# Out:
# 4    0.292607
# 3    0.290137
# 2    0.216532
# 1    0.200725
# Name: household_income, dtype: float64
#
#
# 0 to 25k
# mean fraction 0 to 25k across cohorts = 0.17
# fraction 0 to 25k across all users in cohorts = 0.17
# 25k to 50k
# mean fraction 25k to 50k across cohorts = 0.21
# fraction 25k to 50k across all users in cohorts = 0.21
# 50k to 100k
# mean fraction 50k to 100k across cohorts = 0.29
# fraction 50k to 100k across all users in cohorts = 0.29
# 100k +
# mean fraction 100k + across cohorts = 0.33
# fraction 100k + across all users in cohorts = 0.32
#         household_income  count  total   portion
# cohort
# 1.0                    1     18     98  0.183673
# 1.0                    2     27     98  0.275510
# 1.0                    3     32     98  0.326531
# 1.0                    4     21     98  0.214286
# 2.0                    1     16     86  0.186047

# %% [markdown]
# Looking at combinations of race x household income

# %%
panel_df1['stratify'].value_counts()
# Out:
# 4.0, 1.0    2953
# 3.0, 1.0    2836
# 2.0, 1.0    2016
# 1.0, 1.0    1723
# 1.0, 2.0     530
# 2.0, 2.0     422
# 3.0, 2.0     408
# 4.0, 3.0     269
# 4.0, 2.0     258
# 3.0, 3.0     176
# 3.0, 5.0     104
# 2.0, 3.0     102
# 1.0, 3.0      94
# 1.0, 5.0      91
# 2.0, 5.0      90
# 4.0, 5.0      74
# Name: stratify, dtype: int64

# %%
hi_race1 = plot_cohort_demo_portions(panel_df1, 'stratify', hi_race_values)
hi_race1
# Out:
# 0 to 25k, white
# mean fraction 0 to 25k, white across cohorts = 0.13
# fraction 0 to 25k, white across all users in cohorts = 0.13
# 25k to 50k, white
# mean fraction 25k to 50k, white across cohorts = 0.17
# fraction 25k to 50k, white across all users in cohorts = 0.17
# 50k to 100k, white
# mean fraction 50k to 100k, white across cohorts = 0.24
# fraction 50k to 100k, white across all users in cohorts = 0.24
# 100k +, white
# mean fraction 100k +, white across cohorts = 0.28
# fraction 100k +, white across all users in cohorts = 0.27
# 0 to 25k, black
# mean fraction 0 to 25k, black across cohorts = 0.04
# fraction 0 to 25k, black across all users in cohorts = 0.03
# 25k to 50k, black
# mean fraction 25k to 50k, black across cohorts = 0.03
# fraction 25k to 50k, black across all users in cohorts = 0.03
# 50k to 100k, black
# mean fraction 50k to 100k, black across cohorts = 0.03
# fraction 50k to 100k, black across all users in cohorts = 0.03
# 100k +, black
# mean fraction 100k +, black across cohorts = 0.02
# fraction 100k +, black across all users in cohorts = 0.02
# 0 to 25k, asian
# mean fraction 0 to 25k, asian across cohorts = 0.02
# fraction 0 to 25k, asian across all users in cohorts = 0.01
# 25k to 50k, asian
# mean fraction 25k to 50k, asian across cohorts = 0.02
# fraction 25k to 50k, asian across all users in cohorts = 0.01
# 50k to 100k, asian
# mean fraction 50k to 100k, asian across cohorts = 0.03
# fraction 50k to 100k, asian across all users in cohorts = 0.02
# 100k +, asian
# mean fraction 100k +, asian across cohorts = 0.03
# fraction 100k +, asian across all users in cohorts = 0.03
# 0 to 25k, other
# mean fraction 0 to 25k, other across cohorts = 0.02
# fraction 0 to 25k, other across all users in cohorts = 0.00
# 25k to 50k, other
# mean fraction 25k to 50k, other across cohorts = 0.02
# fraction 25k to 50k, other across all users in cohorts = 0.00
# 50k to 100k, other
# mean fraction 50k to 100k, other across cohorts = 0.02
# fraction 50k to 100k, other across all users in cohorts = 0.01
# 100k +, other
# mean fraction 100k +, other across cohorts = 0.02
# fraction 100k +, other across all users in cohorts = 0.01
#         stratify  count  total   portion
# cohort
# 1.0     1.0, 1.0     12     98  0.122449
# 1.0     1.0, 2.0      6     98  0.061224
# 1.0     2.0, 1.0     19     98  0.193878
# 1.0     2.0, 2.0      6     98  0.061224
# 1.0     2.0, 3.0      1     98  0.010204
# ...          ...    ...    ...       ...
# 78.0    3.0, 3.0      1     69  0.014493
# 78.0    3.0, 5.0      1     69  0.014493
# 78.0    4.0, 1.0     24     69  0.347826
# 78.0    4.0, 2.0      2     69  0.028986
# 78.0    4.0, 3.0      3     69  0.043478
#
# [823 rows x 4 columns]

# %% [markdown]
# Look at "bigger panels" by combining panels. Sample with different weeks.

# %%
# make a panel out of p panel ids
panel_week_combo = get_panel_week_combo(20)
cohorts_dict = prefixLSH.get_cohorts_dict(panel_week_combo.dropna()['simhash'].astype(int), min_k=50)
panel_week_combo['cohort'] = panel_week_combo['simhash'].map(cohorts_dict)

print("%s cohorts" % panel_week_combo["cohort"].nunique())
assert(panel_week_combo["cohort"].max() == panel_week_combo["cohort"].nunique())

panel_week_combo.head()
# Out:
# using panel id, week combos: [(371, 45), (418, 50), (120, 16), (382, 15), (431, 3), (38, 24), (75, 1), (449, 8), (494, 17), (397, 11), (296, 46), (387, 35), (201, 47), (232, 21), (244, 2), (285, 9), (416, 19), (178, 31), (355, 22), (450, 29)]
# 1422 cohorts
#                   household_income  racial_background  stratify  panel_id  \
# machine_id  week
# 177954124.0 24                   1                1.0  1.0, 1.0        38
# 213566733.0 24                   1                1.0  1.0, 1.0        38
# 172751926.0 24                   1                1.0  1.0, 1.0        38
# 228049499.0 24                   1                1.0  1.0, 1.0        38
# 216111256.0 24                   1                1.0  1.0, 1.0        38
#
#                        simhash  cohort
# machine_id  week
# 177954124.0 24             NaN     NaN
# 213566733.0 24             NaN     NaN
# 172751926.0 24             NaN     NaN
# 228049499.0 24             NaN     NaN
# 216111256.0 24    4.034915e+14   453.0

# %%
print('cohort sizes:')
print(panel_week_combo["cohort"].value_counts().describe())

fig,ax = plt.subplots(1,1,figsize=(3,1), dpi=100)
panel_week_combo["cohort"].value_counts().hist(ax=ax)
plt.ylabel("cohorts")
_ = plt.xlabel("cohort size")
plt.show()
fig,ax = plt.subplots(1,1,figsize=(3,1), dpi=100)
panel_week_combo["cohort"].value_counts().hist(ax=ax, bins=50)
plt.ylabel("cohorts")
_ = plt.xlabel("cohort size")
# Out:
# cohort sizes:
# count    1422.000000
# mean       80.566807
# std        21.810991
# min        50.000000
# 25%        63.000000
# 50%        77.000000
# 75%        94.000000
# max       191.000000
# Name: cohort, dtype: float64

# %%
plot_cohort_demo_portions(panel_week_combo, 'racial_background', race_values)
hi = plot_cohort_demo_portions(panel_week_combo, 'household_income', hi_values)
plot_cohort_demo_portions(panel_week_combo, 'stratify', hi_race_values)
# Out:
# white
# mean fraction white across cohorts = 0.81
# fraction white across all users in cohorts = 0.81
# black
# mean fraction black across cohorts = 0.11
# fraction black across all users in cohorts = 0.11
# asian
# mean fraction asian across cohorts = 0.06
# fraction asian across all users in cohorts = 0.06
# other
# mean fraction other across cohorts = 0.03
# fraction other across all users in cohorts = 0.02
# 0 to 25k
# mean fraction 0 to 25k across cohorts = 0.17
# fraction 0 to 25k across all users in cohorts = 0.17
# 25k to 50k
# mean fraction 25k to 50k across cohorts = 0.21
# fraction 25k to 50k across all users in cohorts = 0.21
# 50k to 100k
# mean fraction 50k to 100k across cohorts = 0.30
# fraction 50k to 100k across all users in cohorts = 0.30
# 100k +
# mean fraction 100k + across cohorts = 0.32
# fraction 100k + across all users in cohorts = 0.32
# 0 to 25k, white
# mean fraction 0 to 25k, white across cohorts = 0.13
# fraction 0 to 25k, white across all users in cohorts = 0.13
# 25k to 50k, white
# mean fraction 25k to 50k, white across cohorts = 0.16
# fraction 25k to 50k, white across all users in cohorts = 0.16
# 50k to 100k, white
# mean fraction 50k to 100k, white across cohorts = 0.24
# fraction 50k to 100k, white across all users in cohorts = 0.24
# 100k +, white
# mean fraction 100k +, white across cohorts = 0.27
# fraction 100k +, white across all users in cohorts = 0.27
# 0 to 25k, black
# mean fraction 0 to 25k, black across cohorts = 0.04
# fraction 0 to 25k, black across all users in cohorts = 0.03
# 25k to 50k, black
# mean fraction 25k to 50k, black across cohorts = 0.03
# fraction 25k to 50k, black across all users in cohorts = 0.03
# 50k to 100k, black
# mean fraction 50k to 100k, black across cohorts = 0.03
# fraction 50k to 100k, black across all users in cohorts = 0.03
# 100k +, black
# mean fraction 100k +, black across cohorts = 0.02
# fraction 100k +, black across all users in cohorts = 0.02
# 0 to 25k, asian
# mean fraction 0 to 25k, asian across cohorts = 0.02
# fraction 0 to 25k, asian across all users in cohorts = 0.01
# 25k to 50k, asian
# mean fraction 25k to 50k, asian across cohorts = 0.02
# fraction 25k to 50k, asian across all users in cohorts = 0.01
# 50k to 100k, asian
# mean fraction 50k to 100k, asian across cohorts = 0.02
# fraction 50k to 100k, asian across all users in cohorts = 0.02
# 100k +, asian
# mean fraction 100k +, asian across cohorts = 0.03
# fraction 100k +, asian across all users in cohorts = 0.03
# 0 to 25k, other
# mean fraction 0 to 25k, other across cohorts = 0.02
# fraction 0 to 25k, other across all users in cohorts = 0.01
# 25k to 50k, other
# mean fraction 25k to 50k, other across cohorts = 0.02
# fraction 25k to 50k, other across all users in cohorts = 0.01
# 50k to 100k, other
# mean fraction 50k to 100k, other across cohorts = 0.02
# fraction 50k to 100k, other across all users in cohorts = 0.01
# 100k +, other
# mean fraction 100k +, other across cohorts = 0.02
# fraction 100k +, other across all users in cohorts = 0.01
#         stratify  count  total   portion
# cohort
# 1.0     1.0, 1.0     16    113  0.141593
# 1.0     1.0, 2.0      3    113  0.026549
# 1.0     1.0, 3.0      1    113  0.008850
# 1.0     1.0, 5.0      1    113  0.008850
# 1.0     2.0, 1.0     19    113  0.168142
# ...          ...    ...    ...       ...
# 1422.0  3.0, 3.0      3     91  0.032967
# 1422.0  3.0, 5.0      2     91  0.021978
# 1422.0  4.0, 1.0     20     91  0.219780
# 1422.0  4.0, 2.0      2     91  0.021978
# 1422.0  4.0, 3.0      1     91  0.010989
#
# [16367 rows x 4 columns]

# %% [markdown]
# ### 14 days of data
#
#
# do analysis with more consecutive days of data (e.g. 2 weeks --> 14 days of data) as 7 days was considered a tuneable parameter in initial FLoC implementation and we are currenty dropped a lot of data...

# %% [markdown]
# Create a filtered dataframe that just includes machine,week samples where bad domains have been filtered out and where each sample has at least the threshold number of domains (14).
#
# This requires combining consecutive weeks of data.

# %%
weeks_machines_domains_f_df.drop('machine_id', axis=1).head()
# Out:
#    week  n_domains                                            domains
# 0     1        119  [homeworkmarket.com, shareably.net, crschools....
# 1     1          0                                                 []
# 2     1          2                        [nbcsports.com, google.com]
# 3     1          5  [signaturesalon.us, tasteofhome.com, facebook....
# 4     1          8  [myway.com, victoryoutreach.org, adobeconnect....

# %%
weeks_machines_domains_f_odd_weeks_domains = weeks_machines_domains_f_df[
    (weeks_machines_domains_f_df.week % 2 == 1)
].assign(week_pair=lambda x: x.week).set_index(['machine_id', 'week_pair'])['domains']
weeks_machines_domains_f_odd_weeks_domains.head()
# Out:
# machine_id  week_pair
# 46569906    1            [homeworkmarket.com, shareably.net, crschools....
# 70298839    1                                                           []
# 76984170    1                                  [nbcsports.com, google.com]
# 76991725    1            [signaturesalon.us, tasteofhome.com, facebook....
# 81191519    1            [myway.com, victoryoutreach.org, adobeconnect....
# Name: domains, dtype: object

# %%
weeks_machines_domains_f_even_weeks_domains = weeks_machines_domains_f_df[
    (weeks_machines_domains_f_df.week % 2 == 0)
].assign(week_pair=lambda x: x.week-1).set_index(['machine_id', 'week_pair'])['domains']
weeks_machines_domains_f_even_weeks_domains.head()
# Out:
# machine_id  week_pair
# 46569906    1            [wetpaint.com, fedex.com, skiptomylou.org, gfk...
# 70298839    1                                                           []
# 76984170    1            [foresters.com, jobvite.com, nbcsports.com, go...
# 76991725    1                                                           []
# 81191519    1            [bandsintown.com, navy.mil, usps.gov, active.c...
# Name: domains, dtype: object

# %%
weeks_machines_domains_f_2_weeks_df = (
    weeks_machines_domains_f_odd_weeks_domains + weeks_machines_domains_f_even_weeks_domains
).to_frame().assign(n_domains=lambda x: x.domains.apply(len)).reset_index()

# %%
weeks_machines_domains_f_2_weeks_df
# Out:
#          machine_id  week_pair  \
# 0          46569906          1
# 1          70298839          1
# 2          76984170          1
# 3          76991725          1
# 4          81191519          1
# ...             ...        ...
# 2438613   205133276         51
# 2438614   140934787         51
# 2438615   202867435         51
# 2438616   209945224         51
# 2438617   213961081         51
#
#                                                    domains  n_domains
# 0        [homeworkmarket.com, shareably.net, crschools....        280
# 1                                                       []          0
# 2        [nbcsports.com, google.com, foresters.com, job...          6
# 3        [signaturesalon.us, tasteofhome.com, facebook....          5
# 4        [myway.com, victoryoutreach.org, adobeconnect....         25
# ...                                                    ...        ...
# 2438613                            [megabundlescenter.com]          1
# 2438614                                    [joinhoney.com]          1
# 2438615                                                 []          0
# 2438616                                                 []          0
# 2438617                                                 []          0
#
# [2438618 rows x 4 columns]

# %%
print(weeks_machines_domains_f_2_weeks_df['n_domains'].describe().round())
# Out:
# count    2438618.0
# mean          26.0
# std          325.0
# min            0.0
# 25%            0.0
# 50%           10.0
# 75%           32.0
# max       277208.0
# Name: n_domains, dtype: float64

# %%
# make df limited that limits to samples with at least n_domains_threshold
# and maps machine, week --> simhash
weeks_machines_7domains_2_weeks_df = weeks_machines_domains_f_2_weeks_df[(
    weeks_machines_domains_f_2_weeks_df.n_domains >= n_domains_threshold
)].copy()
print('%0.2f = %s/%s samples with at least %s domains' % (
    len(weeks_machines_7domains_2_weeks_df)/len(weeks_machines_domains_f_2_weeks_df),
    len(weeks_machines_7domains_2_weeks_df), len(weeks_machines_domains_f_2_weeks_df), n_domains_threshold))

print('\nhow many machines per week after filtering?\n')


weeks_machines_7domains_2_weeks = weeks_machines_7domains_2_weeks_df.groupby(['week_pair'])['machine_id'].nunique()
weeks_machines_7domains_2_weeks_pct = weeks_machines_7domains_2_weeks \
    / weeks_machines_domains_f_2_weeks_df.groupby(['week_pair'])['machine_id'].nunique()

print(weeks_machines_7domains_2_weeks.describe())
print(weeks_machines_7domains_2_weeks_pct.describe())

fig, ax = plt.subplots(1,1, figsize=(12, 4), dpi=100)
ax.bar(weeks_machines_7domains_2_weeks.index, weeks_machines_7domains_2_weeks)
ax.set_xlim(0, 53)
ax.set_title('number of machines with at least 7 domains per 2-week period')
ax.set_ylabel('machines')
ax_pct = ax.twinx()
ax_pct.bar(weeks_machines_7domains_2_weeks_pct.index, weeks_machines_7domains_2_weeks_pct)
_ = ax_pct.set_ylabel('% total machines')
# Out:
# 0.56 = 1362843/2438618 samples with at least 7 domains
#
# how many machines per week after filtering?
#
# count       26.000000
# mean     52417.038462
# std       2505.683978
# min      48034.000000
# 25%      50711.750000
# 50%      52453.000000
# 75%      54457.000000
# max      56519.000000
# Name: machine_id, dtype: float64
# count    26.000000
# mean      0.558859
# std       0.026715
# min       0.512128
# 25%       0.540677
# 50%       0.559242
# 75%       0.580608
# max       0.602593
# Name: machine_id, dtype: float64

# %%
# apply simhash to all rows
time_start = datetime.now()
print(time_start)
weeks_machines_7domains_2_weeks_df['simhash'] = weeks_machines_7domains_2_weeks_df.domains.apply(floc.hashes.sim_hash_string)

time_end = datetime.now()
print(time_end - time_start)
# Out:
# 2021-12-01 15:20:21.326068
# 0:12:32.080180

# %%
weeks_machines_7domains_2_weeks_df.head()
# Out:
#    machine_id  week_pair                                            domains  \
# 0    46569906          1  [homeworkmarket.com, shareably.net, crschools....
# 4    81191519          1  [myway.com, victoryoutreach.org, adobeconnect....
# 6    92330491          1  [nathanhowemusic.com, ldsmusiconline.com, make...
# 7    93557605          1  [obsev.com, att.net, auth-gateway.net, msn.com...
# 8    99534294          1  [actionteaser.ru, translarium.info, kasparov.r...
#
#    n_domains           simhash
# 0        280   806111609819321
# 4         25   230462821651608
# 6         56   774410634002354
# 7         19   333081116475406
# 8         73  1073223230102078

# %%
def get_panel_2week_combo(p, debug=True):
    """
    Returns a panel that combines multiple panel ids (p) from different 2-weeks periods.
    where panel ids and weeks are randomly sampled without replacement
    and each panel id is combined with one week
    """
    panel_ids = np.random.choice(panels_df.panel_id.unique(), size=p, replace=False)
    # week pairs are defined by odd integers
    weeks = np.random.choice([w for w in range(1,52+1) if w % 2 == 1], size=p, replace=False)
    if debug:
        print('using panel id, week combos:', list(zip(panel_ids, weeks)))
    pdf = panels_df[panels_df.panel_id.isin(panel_ids)].copy()
    pdf['week_pair'] = pdf.panel_id.map(dict(zip(panel_ids, weeks)))
    pdf = pdf.set_index(['machine_id','week_pair'])
    pdf['simhash'] = weeks_machines_7domains_2_weeks_df.set_index(['machine_id','week_pair'])['simhash']
    return pdf

# %%
p = 1
k = 40

panel_2_weeks_df1 = get_panel_2week_combo(p)

# compute / assign cohorts
# note we will drop / ignore machine,weeks without sufficient domains for simhash

cohorts_dict = prefixLSH.get_cohorts_dict(panel_2_weeks_df1.dropna()['simhash'].astype(int), min_k=k)
panel_2_weeks_df1['cohort'] = panel_2_weeks_df1['simhash'].map(cohorts_dict)

print("%s cohorts" % panel_2_weeks_df1["cohort"].nunique())
assert(panel_2_weeks_df1["cohort"].max() == panel_2_weeks_df1["cohort"].nunique())

print("%s samples (rows)" % len(panel_2_weeks_df1.dropna()))
print("%0.1f avg samples per cohort" % (len(panel_2_weeks_df1.dropna())/panel_2_weeks_df1["cohort"].nunique()))

print('cohort sizes:')
print(panel_2_weeks_df1["cohort"].value_counts().describe())

fig,ax = plt.subplots(1,1,figsize=(3,1), dpi=100)
panel_2_weeks_df1["cohort"].value_counts().hist(ax=ax)
plt.ylabel("cohorts")
_ = plt.xlabel("cohort size")
plt.show()
fig,ax = plt.subplots(1,1,figsize=(3,1), dpi=100)
panel_2_weeks_df1["cohort"].value_counts().hist(ax=ax, bins=50)
plt.ylabel("cohorts")
_ = plt.xlabel("cohort size")
plt.show()

panel_2_weeks_df1.head()
# Out:
# using panel id, week combos: [(286, 51)]
# 110 cohorts
# 6913 samples (rows)
# 62.8 avg samples per cohort
# cohort sizes:
# count    110.000000
# mean      62.845455
# std       16.069337
# min       41.000000
# 25%       49.000000
# 50%       62.000000
# 75%       75.000000
# max      103.000000
# Name: cohort, dtype: float64
#                        household_income  racial_background  stratify  \
# machine_id  week_pair
# 190378472.0 51                        1                1.0  1.0, 1.0
# 214237911.0 51                        1                1.0  1.0, 1.0
# 220772342.0 51                        1                1.0  1.0, 1.0
# 211233701.0 51                        1                1.0  1.0, 1.0
# 219151666.0 51                        1                1.0  1.0, 1.0
#
#                        panel_id  simhash  cohort
# machine_id  week_pair
# 190378472.0 51              286      NaN     NaN
# 214237911.0 51              286      NaN     NaN
# 220772342.0 51              286      NaN     NaN
# 211233701.0 51              286      NaN     NaN
# 219151666.0 51              286      NaN     NaN

# %%
_ = plot_cohort_demo_portions(panel_2_weeks_df1, 'racial_background', race_values)
_ = plot_cohort_demo_portions(panel_2_weeks_df1, 'household_income', hi_values)
_ = plot_cohort_demo_portions(panel_2_weeks_df1, 'stratify', hi_race_values)
# Out:
# white
# mean fraction white across cohorts = 0.80
# fraction white across all users in cohorts = 0.80
# black
# mean fraction black across cohorts = 0.11
# fraction black across all users in cohorts = 0.11
# asian
# mean fraction asian across cohorts = 0.06
# fraction asian across all users in cohorts = 0.06
# other
# mean fraction other across cohorts = 0.03
# fraction other across all users in cohorts = 0.02
# 0 to 25k
# mean fraction 0 to 25k across cohorts = 0.18
# fraction 0 to 25k across all users in cohorts = 0.18
# 25k to 50k
# mean fraction 25k to 50k across cohorts = 0.21
# fraction 25k to 50k across all users in cohorts = 0.21
# 50k to 100k
# mean fraction 50k to 100k across cohorts = 0.29
# fraction 50k to 100k across all users in cohorts = 0.29
# 100k +
# mean fraction 100k + across cohorts = 0.32
# fraction 100k + across all users in cohorts = 0.32
# 0 to 25k, white
# mean fraction 0 to 25k, white across cohorts = 0.13
# fraction 0 to 25k, white across all users in cohorts = 0.13
# 25k to 50k, white
# mean fraction 25k to 50k, white across cohorts = 0.17
# fraction 25k to 50k, white across all users in cohorts = 0.17
# 50k to 100k, white
# mean fraction 50k to 100k, white across cohorts = 0.24
# fraction 50k to 100k, white across all users in cohorts = 0.24
# 100k +, white
# mean fraction 100k +, white across cohorts = 0.27
# fraction 100k +, white across all users in cohorts = 0.27
# 0 to 25k, black
# mean fraction 0 to 25k, black across cohorts = 0.04
# fraction 0 to 25k, black across all users in cohorts = 0.04
# 25k to 50k, black
# mean fraction 25k to 50k, black across cohorts = 0.04
# fraction 25k to 50k, black across all users in cohorts = 0.03
# 50k to 100k, black
# mean fraction 50k to 100k, black across cohorts = 0.03
# fraction 50k to 100k, black across all users in cohorts = 0.03
# 100k +, black
# mean fraction 100k +, black across cohorts = 0.03
# fraction 100k +, black across all users in cohorts = 0.02
# 0 to 25k, asian
# mean fraction 0 to 25k, asian across cohorts = 0.02
# fraction 0 to 25k, asian across all users in cohorts = 0.01
# 25k to 50k, asian
# mean fraction 25k to 50k, asian across cohorts = 0.02
# fraction 25k to 50k, asian across all users in cohorts = 0.01
# 50k to 100k, asian
# mean fraction 50k to 100k, asian across cohorts = 0.03
# fraction 50k to 100k, asian across all users in cohorts = 0.02
# 100k +, asian
# mean fraction 100k +, asian across cohorts = 0.03
# fraction 100k +, asian across all users in cohorts = 0.03
# 0 to 25k, other
# mean fraction 0 to 25k, other across cohorts = 0.02
# fraction 0 to 25k, other across all users in cohorts = 0.01
# 25k to 50k, other
# mean fraction 25k to 50k, other across cohorts = 0.02
# fraction 25k to 50k, other across all users in cohorts = 0.01
# 50k to 100k, other
# mean fraction 50k to 100k, other across cohorts = 0.02
# fraction 50k to 100k, other across all users in cohorts = 0.01
# 100k +, other
# mean fraction 100k +, other across cohorts = 0.02
# fraction 100k +, other across all users in cohorts = 0.01
